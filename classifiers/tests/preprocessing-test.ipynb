# %%
import os

# Function to change to the parent directory
def change_to_parent_directory():
    # Check if the directory has already been changed
    if not os.environ.get('DIR_CHANGED'):
        try:
            current_dir = os.path.dirname(os.path.abspath(__file__))
        except NameError:
            current_dir = os.getcwd()
        parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
        os.chdir(parent_dir)
        os.environ['DIR_CHANGED'] = '1'
        print(f"Current working directory changed to: {os.getcwd()}")
    else:
        print("Directory has already been changed.")

# Call the function to change the working directory
change_to_parent_directory()
# Out:
# Current working directory changed to: /home/ihranicky/git/domainradar-clf/classifiers

# %% [markdown]
# # Optional - Create a testing parquet

# %%
create_test_parquet = True

if create_test_parquet:
    import pandas as pd
    import numpy as np
    
    # List of input Parquet files
    input_files = [
        'testdata/misp_2402.parquet',
        'testdata/benign_2312.parquet'
    ]
    
    # Number of rows to select
    n_rows = 1000
    
    # Read all Parquet files into a single DataFrame
    dataframes = [pd.read_parquet(file) for file in input_files]
    combined_df = pd.concat(dataframes, ignore_index=True)
    
    # Randomly select n_rows rows from the combined DataFrame
    selected_rows = combined_df.sample(n=n_rows, random_state=1)  # random_state for reproducibility
    
    # Save the selected rows to a new Parquet file
    selected_rows.to_parquet('testdata/sample.parquet')
    
    # Display the selected rows
    print(selected_rows)
# Out:
#                                    domain_name                label  \
# 200645                        mp4moviez.sydney  benign_2312:unknown
# 238746                          tsunagu.ryukyu  benign_2312:unknown
# 247069  6036825.global.siteimproveanalytics.io  benign_2312:unknown
# 166511                       assalaamair.co.tz  benign_2312:unknown
# 284693                             ogorod.guru  benign_2312:unknown
# ...                                        ...                  ...
# 522556                          mni.1slogir.vg  benign_2312:unknown
# 302846                        monteazul.com.pe  benign_2312:unknown
# 109903                         kaducollect.com   misp_2310:phishing
# 156130   search-bcarchives.royalbcmuseum.bc.ca  benign_2312:unknown
# 432252                     n.cngunadvised.buzz  benign_2312:unknown
#
#         dns_has_dnskey  dns_A_count  dns_AAAA_count  dns_MX_count  \
# 200645             0.0            2               2             0
# 238746             0.0            1               0             1
# 247069             0.0            0               0             0
# 166511             0.0            1               0             1
# 284693             0.0            1               0             1
# ...                ...          ...             ...           ...
# 522556             1.0            1               0             0
# 302846             0.0            1               0             1
# 109903             0.0            1               0             2
# 156130             0.0            1               0             0
# 432252             0.0            2               2             0
#
#         dns_NS_count  dns_TXT_count  dns_SOA_count  dns_CNAME_count  ...  \
# 200645             2              1              1                0  ...
# 238746             2              0              1                0  ...
# 247069             0              0              0                0  ...
# 166511             3              1              1                0  ...
# 284693             4              0              1                0  ...
# ...              ...            ...            ...              ...  ...
# 522556             0              0              0                0  ...
# 302846             2              1              1                0  ...
# 109903             2              2              1                0  ...
# 156130             0              0              0                0  ...
# 432252             0              0              0                0  ...
#
#         rdap_ip_v4_count  rdap_ip_v6_count  rdap_ip_shortest_v4_prefix_len  \
# 200645                 8                 8                              13
# 238746                 3                 0                              24
# 247069                 0                 0                               0
# 166511                 3                 0                              22
# 284693                 5                 1                              21
# ...                  ...               ...                             ...
# 522556                 1                 0                              20
# 302846                10                 0                              12
# 109903                 9                 6                              11
# 156130                 1                 0                              16
# 432252                 2                 2                              12
#
#         rdap_ip_longest_v4_prefix_len  rdap_ip_shortest_v6_prefix_len  \
# 200645                             22                              32
# 238746                             24                               0
# 247069                              0                               0
# 166511                             24                               0
# 284693                             27                              29
# ...                               ...                             ...
# 522556                             20                               0
# 302846                             17                               0
# 109903                             20                              32
# 156130                             16                               0
# 432252                             13                              32
#
#         rdap_ip_longest_v6_prefix_len  rdap_ip_avg_admin_name_len  \
# 200645                             32                   15.125000
# 238746                              0                   32.000000
# 247069                              0                    0.000000
# 166511                              0                   18.000000
# 284693                             29                   21.000000
# ...                               ...                         ...
# 522556                              0                   13.000000
# 302846                              0                   21.500000
# 109903                             32                   13.933333
# 156130                              0                   17.000000
# 432252                             32                    5.000000
#
#         rdap_ip_avg_admin_name_entropy  rdap_ip_avg_admin_email_len  \
# 200645                        0.311047                    11.250000
# 238746                        0.120577                    20.000000
# 247069                        0.000000                     0.000000
# 166511                        0.123085                     9.750000
# 284693                        0.183612                     8.166667
# ...                                ...                          ...
# 522556                        0.249146                    17.000000
# 302846                        0.170166                    23.900000
# 109903                        0.326186                    18.200000
# 156130                        0.210145                    17.000000
# 432252                        0.464386                    18.000000
#
#         rdap_ip_avg_admin_email_entropy
# 200645                         0.123752
# 238746                         0.196096
# 247069                         0.000000
# 166511                         0.204611
# 284693                         0.112327
# ...                                 ...
# 522556                         0.223986
# 302846                         0.152810
# 109903                         0.196278
# 156130                         0.212757
# 432252                         0.198468
#
# [1000 rows x 178 columns]

# %% [markdown]
# # Make a test run of conversion into NDF

# %%
import pandas as pd
from preprocessor import Preprocessor

test_dataset = 'testdata/sample.parquet'

pp = Preprocessor()

domain_data = pd.read_parquet(test_dataset)

for index, row in domain_data.iterrows():
    domain_name = row['domain_name']
    original_label = row['label']
    
    print(f"{index}: {domain_name} - {original_label}")
    
    feature_vector = pd.DataFrame([row])
    feature_vector.drop(columns=['domain_name', 'label'], inplace=True)
    
    ndf = pp.NDF(feature_vector, 'phishing')
    print(type(ndf))
# Out:
# 200645: mp4moviez.sydney - benign_2312:unknown
# <class 'dict'>
# 238746: tsunagu.ryukyu - benign_2312:unknown
# <class 'dict'>
# 247069: 6036825.global.siteimproveanalytics.io - benign_2312:unknown
# <class 'dict'>
# 166511: assalaamair.co.tz - benign_2312:unknown
# <class 'dict'>
# 284693: ogorod.guru - benign_2312:unknown
# <class 'dict'>
# 39856: haaberkorn.github.io - phishing_since_2402:phishing
# <class 'dict'>
# 491855: anuarioseguros.lat - benign_2312:unknown
# <class 'dict'>
# 401138: maavarim.mod.gov.il - benign_2312:unknown
# <class 'dict'>
# 550439: athonor.defensoria-nsjp.gob.mx - benign_2312:unknown
# <class 'dict'>
# 547103: dickofdogcom.z00.monster - benign_2312:unknown
# <class 'dict'>
# 270013: skygx.store - benign_2312:unknown
# <class 'dict'>
# 414224: mop-shoot.tauri.hu - benign_2312:unknown
# <class 'dict'>
# 335453: exidmet.justice.gov.az - benign_2312:unknown
# <class 'dict'>
# 183535: misericordia.mb.ca - benign_2312:unknown
# <class 'dict'>
# 511909: cassady.family - benign_2312:unknown
# <class 'dict'>
# 254001: h109381-ecdn.mp.lura.live - benign_2312:unknown
# <class 'dict'>
# 273161: americanlaundry.mx - benign_2312:unknown
# <class 'dict'>
# 83737: banrura1.web.app - misp_2310:phishing
# <class 'dict'>
# 251459: cloud.trinka.ai - benign_2312:unknown
# <class 'dict'>
# 352010: fdit.llc - benign_2312:unknown
# <class 'dict'>
# 165608: oxygene.sm - benign_2312:unknown
# <class 'dict'>
# 496318: skc.org.rs - benign_2312:unknown
# <class 'dict'>
# 536413: familyswap.xxx - benign_2312:unknown
# <class 'dict'>
# 470266: fotv.sbs - benign_2312:unknown
# <class 'dict'>
# 322263: astat.provinz.bz.it - benign_2312:unknown
# <class 'dict'>
# 310503: pg.camcom.gov.it - benign_2312:unknown
# <class 'dict'>
# 316725: psico.tips - benign_2312:unknown
# <class 'dict'>
# 25897: usqyme.top - phishing_since_2402:phishing
# <class 'dict'>
# 344616: s.wealth.bnpparibas.mc - benign_2312:unknown
# <class 'dict'>
# 509029: shaherezada.vn.ua - benign_2312:unknown
# <class 'dict'>
# 119531: cpnsss.gouv.qc.ca - benign_2312:unknown
# <class 'dict'>
# 434110: anatech.com.ng - benign_2312:unknown
# <class 'dict'>
# 444362: text-crdt-compare.surge.sh - benign_2312:unknown
# <class 'dict'>
# 539927: digitalfire.agency - benign_2312:unknown
# <class 'dict'>
# 176401: brasilhentai.blog.br - benign_2312:unknown
# <class 'dict'>
# 185222: eshop.orange.jo - benign_2312:unknown
# <class 'dict'>
# 409390: allxumuk.ru - benign_2312:unknown
# <class 'dict'>
# 387814: flab.cv.ua - benign_2312:unknown
# <class 'dict'>
# 230744: cciampnr.cg - benign_2312:unknown
# <class 'dict'>
# 511345: bios.edu.uy - benign_2312:unknown
# <class 'dict'>
# 342648: ciproc.ucr.ac.cr - benign_2312:unknown
# <class 'dict'>
# 569348: nahapetyan.training - benign_2312:unknown
# <class 'dict'>
# 542543: jari.or.jp - benign_2312:unknown
# <class 'dict'>
# 332143: paws.org.my - benign_2312:unknown
# <class 'dict'>
# 20624: sign-in-att-103747.weeblysite.com - phishing_since_2402:phishing
# <class 'dict'>
# 17446: usprs-vip.top - phishing_since_2402:phishing
# <class 'dict'>
# 91345: bafybeibgjwxg4fhc2c7jaio4xx7ngsxffwkwwwpded44ea7xsomihfdmgu.ipfs.infura-ipfs.io - misp_2310:phishing
# <class 'dict'>
# 312426: soi.ink - benign_2312:unknown
# <class 'dict'>
# 330989: iht.hn - benign_2312:unknown
# <class 'dict'>
# 259399: oulu.digitransit.fi - benign_2312:unknown
# <class 'dict'>
# 27204: exoduiswalleth.gitbook.io - phishing_since_2402:phishing
# <class 'dict'>
# 465976: acyclovir.wtf - benign_2312:unknown
# <class 'dict'>
# 424029: vime.one - benign_2312:unknown
# <class 'dict'>
# 108120: reserviciosgenerales.com - misp_2310:phishing
# <class 'dict'>
# 241895: leadinstitute.dm - benign_2312:unknown
# <class 'dict'>
# 356219: datenvernichtung.green - benign_2312:unknown
# <class 'dict'>
# 132926: 777.porn - benign_2312:unknown
# <class 'dict'>
# 480437: we4u.net.br - benign_2312:unknown
# <class 'dict'>
# 254511: images.ixbt.site - benign_2312:unknown
# <class 'dict'>
# 463631: doenv.gov.np - benign_2312:unknown
# <class 'dict'>
# 348039: freeproducts.deals - benign_2312:unknown
# <class 'dict'>
# 226863: bembolado.esp.br - benign_2312:unknown
# <class 'dict'>
# 289734: demo.ews.pe - benign_2312:unknown
# <class 'dict'>
# 343489: edc.library.unic.ac.cy - benign_2312:unknown
# <class 'dict'>
# 304702: files.18av.moe - benign_2312:unknown
# <class 'dict'>
# 20574: ccvvsceduvalid.ukit.me - phishing_since_2402:phishing
# <class 'dict'>
# 393658: pla-cole.wedding - benign_2312:unknown
# <class 'dict'>
# 376166: cleaningequipmentservices.limited - benign_2312:unknown
# <class 'dict'>
# 368692: mmsn.org.np - benign_2312:unknown
# <class 'dict'>
# 40997: boostyoursnapscore.blogspot.com.by - phishing_since_2402:phishing
# <class 'dict'>
# 188813: journal.pan.olsztyn.pl - benign_2312:unknown
# <class 'dict'>
# 493664: cekunda.watch - benign_2312:unknown
# <class 'dict'>
# 130772: copo.edu.rs - benign_2312:unknown
# <class 'dict'>
# 263151: ipliroforia.gr - benign_2312:unknown
# <class 'dict'>
# 259269: mandiner.hu - benign_2312:unknown
# <class 'dict'>
# 366236: etecapan.cps.sp.gov.br - benign_2312:unknown
# <class 'dict'>
# 388646: nisiki.nagoya - benign_2312:unknown
# <class 'dict'>
# 15611: coin-change.com - phishing_since_2402:phishing
# <class 'dict'>
# 456942: levis.sggw.waw.pl - benign_2312:unknown
# <class 'dict'>
# 100116: tunahrtjanzak10.web.app - misp_2310:phishing
# <class 'dict'>
# 221263: bamboo.joburg - benign_2312:unknown
# <class 'dict'>
# 485438: zyx.foundation - benign_2312:unknown
# <class 'dict'>
# 232613: nativacontabilidade.cnt.br - benign_2312:unknown
# <class 'dict'>
# 28517: xgeasdshsgd.blogspot.com - phishing_since_2402:phishing
# <class 'dict'>
# 475961: laclave.com.py - benign_2312:unknown
# <class 'dict'>
# 458998: automat.systems - benign_2312:unknown
# <class 'dict'>
# 527694: redditpx.jeffjose.cloud - benign_2312:unknown
# <class 'dict'>
# 420125: dn.genie.co.kr - benign_2312:unknown
# <class 'dict'>
# 127233: consent.wowbiz.ro - benign_2312:unknown
# <class 'dict'>
# 417094: vid1674118991.vb17121coramclean.pw - benign_2312:unknown
# <class 'dict'>
# 456503: sklep.mpm.net.pl - benign_2312:unknown
# <class 'dict'>
# 244178: interior.gov.lb - benign_2312:unknown
# <class 'dict'>
# 458740: pnlretailshop.mu - benign_2312:unknown
# <class 'dict'>
# 28283: mail.captiv8axosinfluencer.com - phishing_since_2402:phishing
# <class 'dict'>
# 298565: banter.so - benign_2312:unknown
# <class 'dict'>
# 218859: ubuy.com.ki - benign_2312:unknown
# <class 'dict'>
# 481341: agro.jobs - benign_2312:unknown
# <class 'dict'>
# 481941: turismosopo.gov.co - benign_2312:unknown
# <class 'dict'>
# 326260: nic.je - benign_2312:unknown
# <class 'dict'>
# 315849: animator.opole.pl - benign_2312:unknown
# <class 'dict'>
# 522743: mathscinet-ams-org.ezproxy.ulb.ac.be - benign_2312:unknown
# <class 'dict'>
# 473576: blog.knopdusa.pages.fit - benign_2312:unknown
# <class 'dict'>
# 41541: cacheddocs.appspot.com - phishing_since_2402:phishing
# <class 'dict'>
# 359256: tadibel.tj - benign_2312:unknown
# <class 'dict'>
# 398446: ncc.gov.jm - benign_2312:unknown
# <class 'dict'>
# 275783: leanback.digital - benign_2312:unknown
# <class 'dict'>
# 14010: solitary-surf-f75c.utfsftov.workers.dev - phishing_since_2402:phishing
# <class 'dict'>
# 120269: cs-wikipedia-org.translate.goog - benign_2312:unknown
# <class 'dict'>
# 166201: analytics.tower.nf - benign_2312:unknown
# <class 'dict'>
# 440348: culture.am - benign_2312:unknown
# <class 'dict'>
# 348695: moveco.com.gt - benign_2312:unknown
# <class 'dict'>
# 344542: fhce.edu.uy - benign_2312:unknown
# <class 'dict'>
# 3070: dswmegadigital.com - phishing_since_2402:phishing
# <class 'dict'>
# 284640: oceano.com.co - benign_2312:unknown
# <class 'dict'>
# 400418: ojung.sen.es.kr - benign_2312:unknown
# <class 'dict'>
# 160883: admediosnoticias.com.do - benign_2312:unknown
# <class 'dict'>
# 244002: opac.library.hb.cn - benign_2312:unknown
# <class 'dict'>
# 412189: gfs262n335.userstorage.mega.co.nz - benign_2312:unknown
# <class 'dict'>
# 123967: ilocr.iiit.ac.in - benign_2312:unknown
# <class 'dict'>
# 273062: xn--80aeeytd1a.xn--p1ai - benign_2312:unknown
# <class 'dict'>
# 430402: demo.vdocuments.mx - benign_2312:unknown
# <class 'dict'>
# 96576: global_errors.sitebeat.crazydomains.com - misp_2310:phishing
# <class 'dict'>
# 292904: governor.support - benign_2312:unknown
# <class 'dict'>
# 12938: hotmail-108490.weeblysite.com - phishing_since_2402:phishing
# <class 'dict'>
# 53190: metafb-shf4839.web.app - misp_2310:phishing
# <class 'dict'>
# 273931: boom-v1.view.rocks - benign_2312:unknown
# <class 'dict'>
# 539894: desn.kyivcity.gov.ua - benign_2312:unknown
# <class 'dict'>
# 536558: shop.graphicube.lu - benign_2312:unknown
# <class 'dict'>
# 436778: csp-report.shopgate.services - benign_2312:unknown
# <class 'dict'>
# 486942: aloe.cool - benign_2312:unknown
# <class 'dict'>
# 41234: walken-nft.web.app - phishing_since_2402:phishing
# <class 'dict'>
# 71095: amendes-gouvfr.fr - misp_2310:phishing
# <class 'dict'>
# 269143: rejestrymedyczne.ezdrowie.gov.pl - benign_2312:unknown
# <class 'dict'>
# 180790: islamabad.embaixadaportugal.mne.gov.pt - benign_2312:unknown
# <class 'dict'>
# 123225: kjndjnocakcc5y9wd.ay.delivery - benign_2312:unknown
# <class 'dict'>
# 90151: attmailboxxwes1.wixsite.com - misp_2310:phishing
# <class 'dict'>
# 241201: athi.abbott - benign_2312:unknown
# <class 'dict'>
# 255061: img69.imageshack.us - benign_2312:unknown
# <class 'dict'>
# 366417: cue.or.ke - benign_2312:unknown
# <class 'dict'>
# 146412: float.tychy.pl - benign_2312:unknown
# <class 'dict'>
# 294479: donauspital.wien - benign_2312:unknown
# <class 'dict'>
# 475564: 3tmadeinitaly.bike - benign_2312:unknown
# <class 'dict'>
# 464437: ntpu.edu.tw - benign_2312:unknown
# <class 'dict'>
# 230896: spmi.ac.pr - benign_2312:unknown
# <class 'dict'>
# 182360: shinigami.band - benign_2312:unknown
# <class 'dict'>
# 303375: boards.wekan.team - benign_2312:unknown
# <class 'dict'>
# 250463: cdn.sbcdn.it - benign_2312:unknown
# <class 'dict'>
# 229457: advokati.odessa.ua - benign_2312:unknown
# <class 'dict'>
# 200769: vmro-dpmne.org.mk - benign_2312:unknown
# <class 'dict'>
# 311997: marondera.opencouncil.co.zw - benign_2312:unknown
# <class 'dict'>
# 248190: api.ichro.me - benign_2312:unknown
# <class 'dict'>
# 441346: mathematicians.korea.ac.kr - benign_2312:unknown
# <class 'dict'>
# 286190: win-loss.agency - benign_2312:unknown
# <class 'dict'>
# 238544: webmail.27r.gop - benign_2312:unknown
# <class 'dict'>
# 106321: hotmail-108755.weeblysite.com - misp_2310:phishing
# <class 'dict'>
# 194042: garmian.edu.krd - benign_2312:unknown
# <class 'dict'>
# 146735: lviv.billing.city - benign_2312:unknown
# <class 'dict'>
# 225712: tarbawej.elmergib.edu.ly - benign_2312:unknown
# <class 'dict'>
# 157606: castironradiators.ltd.uk - benign_2312:unknown
# <class 'dict'>
# 440429: api-veri.player.im - benign_2312:unknown
# <class 'dict'>
# 90887: ads-restricted-notify-79054.web.app - misp_2310:phishing
# <class 'dict'>
# 187946: cr3.org.pe - benign_2312:unknown
# <class 'dict'>
# 405909: mmuni.1sjogin.vg - benign_2312:unknown
# <class 'dict'>
# 314942: globalenergy.com.sa - benign_2312:unknown
# <class 'dict'>
# 210685: elin.com.al - benign_2312:unknown
# <class 'dict'>
# 298342: apply.esmt.berlin - benign_2312:unknown
# <class 'dict'>
# 237311: jb-wolchon.es.kr - benign_2312:unknown
# <class 'dict'>
# 184089: uba.mg.leg.br - benign_2312:unknown
# <class 'dict'>
# 116717: a-v2.vtvdigital.vn - benign_2312:unknown
# <class 'dict'>
# 463968: kams.ktcu.or.kr - benign_2312:unknown
# <class 'dict'>
# 313666: istanawedding.my.id - benign_2312:unknown
# <class 'dict'>
# 442325: hobbylobby.com.pk - benign_2312:unknown
# <class 'dict'>
# 343803: neonvegas.casino - benign_2312:unknown
# <class 'dict'>
# 146372: ilment.com.pk - benign_2312:unknown
# <class 'dict'>
# 189643: ishibi.pref.ishikawa.jp - benign_2312:unknown
# <class 'dict'>
# 531336: oliveyoung.co.kr - benign_2312:unknown
# <class 'dict'>
# 297402: mybottle.web.id - benign_2312:unknown
# <class 'dict'>
# 534175: marioblock.com.ar - benign_2312:unknown
# <class 'dict'>
# 369159: inrb.cd - benign_2312:unknown
# <class 'dict'>
# 542214: dhw.ac.jp - benign_2312:unknown
# <class 'dict'>
# 145372: estate123.my - benign_2312:unknown
# <class 'dict'>
# 571608: auth.prohealth.or.at - benign_2312:unknown
# <class 'dict'>
# 248285: api.jssp.tv - benign_2312:unknown
# <class 'dict'>
# 11374: php-green-oyster-demetriusrodrigues23684372.codeanyapp.com - phishing_since_2402:phishing
# <class 'dict'>
# 103473: dodge.kraftonevent.com - misp_2310:phishing
# <class 'dict'>
# 500814: tajbay.tj - benign_2312:unknown
# <class 'dict'>
# 535928: venuecollection.qut.edu.au - benign_2312:unknown
# <class 'dict'>
# 213201: emsisoft.co.ir - benign_2312:unknown
# <class 'dict'>
# 53240: outlook-web-269d2.firebaseapp.com - misp_2310:phishing
# <class 'dict'>
# 339170: milker.cafe - benign_2312:unknown
# <class 'dict'>
# 438512: tangled.im - benign_2312:unknown
# <class 'dict'>
# 542001: images.mychannels.games - benign_2312:unknown
# <class 'dict'>
# 521830: dimaniyattours.om - benign_2312:unknown
# <class 'dict'>
# 546352: sjvn.nic.in - benign_2312:unknown
# <class 'dict'>
# 21120: vfrontier-crew.pages.dev - phishing_since_2402:phishing
# <class 'dict'>
# 358406: madeye.brussels - benign_2312:unknown
# <class 'dict'>
# 201173: dclawyers.co.ao - benign_2312:unknown
# <class 'dict'>
# 59363: huidianxun.com - misp_2310:phishing
# <class 'dict'>
# 35652: postbao.cfd - phishing_since_2402:phishing
# <class 'dict'>
# 364276: image.yts.je - benign_2312:unknown
# <class 'dict'>
# 422257: 3magygih6pcf.l4.adsco.re - benign_2312:unknown
# <class 'dict'>
# 204487: uk.mfa.gov.ge - benign_2312:unknown
# <class 'dict'>
# 79559: att-109027.weeblysite.com - misp_2310:phishing
# <class 'dict'>
# 70739: six.bugaros.com - misp_2310:phishing
# <class 'dict'>
# 116088: arteterapia.org.es - benign_2312:unknown
# <class 'dict'>
# 11633: pub-274a63587257423b942a17bc7068aa18.r2.dev - phishing_since_2402:phishing
# <class 'dict'>
# 485372: kingsway.farm - benign_2312:unknown
# <class 'dict'>
# 396542: hi-tech.rent - benign_2312:unknown
# <class 'dict'>
# 290792: ksmc.karnataka.gov.in - benign_2312:unknown
# <class 'dict'>
# 160320: tiendasantillana.com.do - benign_2312:unknown
# <class 'dict'>
# 256676: bafkreihid64uqcnzwa2baymdm6usekzdtcqzzffcemnrwln4tz5h7bguui.ipfs.dweb.link - benign_2312:unknown
# <class 'dict'>
# 565466: altafrequencia.ind.br - benign_2312:unknown
# <class 'dict'>
# 269945: static2.myrunning.uk - benign_2312:unknown
# <class 'dict'>
# 246422: wired.rehab - benign_2312:unknown
# <class 'dict'>
# 327860: hub.dm.gov.ae - benign_2312:unknown
# <class 'dict'>
# 9735: servi-ces.live-updates.workers.dev - phishing_since_2402:phishing
# <class 'dict'>
# 437826: koi-3qnlgo0vji.marketingautomation.services - benign_2312:unknown
# <class 'dict'>
# 148091: renanas.kitchen - benign_2312:unknown
# <class 'dict'>
# 541443: nepoceda.kiev.ua - benign_2312:unknown
# <class 'dict'>
# 396749: motorcity.bh - benign_2312:unknown
# <class 'dict'>
# 234244: comune.legnano.mi.it - benign_2312:unknown
# <class 'dict'>
# 489717: czech.photos - benign_2312:unknown
# <class 'dict'>
# 157042: uk.casino.help - benign_2312:unknown
# <class 'dict'>
# 487764: bna.edu.ng - benign_2312:unknown
# <class 'dict'>
# 535556: makeway.world - benign_2312:unknown
# <class 'dict'>
# 345728: nspri.gov.ng - benign_2312:unknown
# <class 'dict'>
# 280607: wargabiz.com.my - benign_2312:unknown
# <class 'dict'>
# 257606: img.watchserieshd.live - benign_2312:unknown
# <class 'dict'>
# 430436: cover.mr-jatt.im - benign_2312:unknown
# <class 'dict'>
# 340201: n-alps.beer - benign_2312:unknown
# <class 'dict'>
# 486721: unmute.band - benign_2312:unknown
# <class 'dict'>
# 490734: access-1clarivate-1com-100006101305b.han.uni.opole.pl - benign_2312:unknown
# <class 'dict'>
# 275986: leminhkhai.blog - benign_2312:unknown
# <class 'dict'>
# 234361: comune.sanza.sa.it - benign_2312:unknown
# <class 'dict'>
# 113201: alcdn.msauth.net.mcas.ms - benign_2312:unknown
# <class 'dict'>
# 289024: wodonga.vic.gov.au - benign_2312:unknown
# <class 'dict'>
# 15752: www.barbaracomstockforcongress444.tankfilthhounds.net - phishing_since_2402:phishing
# <class 'dict'>
# 302537: kadamchoeling.or.id - benign_2312:unknown
# <class 'dict'>
# 269985: sanluispotosi.quadratin.com.mx - benign_2312:unknown
# <class 'dict'>
# 367071: kollib.if.ua - benign_2312:unknown
# <class 'dict'>
# 209885: lib-6sspss6qnvvv3cv5pjqrmp2n.resist.tel - benign_2312:unknown
# <class 'dict'>
# 155908: oak.go.kr - benign_2312:unknown
# <class 'dict'>
# 400671: seouldongsan.sen.hs.kr - benign_2312:unknown
# <class 'dict'>
# 238744: transparencia.ac.gov.br - benign_2312:unknown
# <class 'dict'>
# 402088: spgroup.prod.fire.glass - benign_2312:unknown
# <class 'dict'>
# 314781: nurseryglider.reviews - benign_2312:unknown
# <class 'dict'>
# 233099: irac.pe.ca - benign_2312:unknown
# <class 'dict'>
# 86459: telebankingwebe.online - misp_2310:phishing
# <class 'dict'>
# 128718: sentry.fxpro.technology - benign_2312:unknown
# <class 'dict'>
# 116005: arc-widgets.lanacion.com.ar - benign_2312:unknown
# <class 'dict'>
# 559832: theta.eco - benign_2312:unknown
# <class 'dict'>
# 407916: 1-0511.b-cdn.net - benign_2312:unknown
# <class 'dict'>
# 282542: educationalcentre.al - benign_2312:unknown
# <class 'dict'>
# 57016: library.polkastqrtter.com - misp_2310:phishing
# <class 'dict'>
# 192740: policiales.pnc.gob.gt - benign_2312:unknown
# <class 'dict'>
# 263442: x.cnnccreceptive.buzz - benign_2312:unknown
# <class 'dict'>
# 406866: bilateral-austria.nitra.gov.rs - benign_2312:unknown
# <class 'dict'>
# 268488: phy.iiserbpr.ac.in - benign_2312:unknown
# <class 'dict'>
# 472701: smstor34.grid.sinica.edu.tw - benign_2312:unknown
# <class 'dict'>
# 16995: felipegomez.co - phishing_since_2402:phishing
# <class 'dict'>
# 284621: media.quiksilverkorea.kr - benign_2312:unknown
# <class 'dict'>
# 95008: pub-405811e2058f4647ace4c46af3bb92c7.r2.dev - misp_2310:phishing
# <class 'dict'>
# 58401: securespend.admitcardx.in - misp_2310:phishing
# <class 'dict'>
# 395197: hyperhidrosis.equipment - benign_2312:unknown
# <class 'dict'>
# 344888: bn.wim.mil.pl - benign_2312:unknown
# <class 'dict'>
# 566832: apps.tu.edu.sa - benign_2312:unknown
# <class 'dict'>
# 327448: 50.haifa.ac.il - benign_2312:unknown
# <class 'dict'>
# 332519: mers.uaz.edu.mx - benign_2312:unknown
# <class 'dict'>
# 67893: aol-107794.weeblysite.com - misp_2310:phishing
# <class 'dict'>
# 45552: amazon-b8.shop - misp_2310:phishing
# <class 'dict'>
# 386379: radio.fish - benign_2312:unknown
# <class 'dict'>
# 19116: 5432.rozajee.com - phishing_since_2402:phishing
# <class 'dict'>
# 22818: attmailaccountupdatingyahoonetkljasioiriouejchsdhgfhasxe.weebly.com - phishing_since_2402:phishing
# <class 'dict'>
# 55017: www.brooksnewmethod.top - misp_2310:phishing
# <class 'dict'>
# 425955: casebook.leeds.ac.uk - benign_2312:unknown
# <class 'dict'>
# 355661: api.nft.kred - benign_2312:unknown
# <class 'dict'>
# 89679: business-case-appeal-218412.firebaseapp.com - misp_2310:phishing
# <class 'dict'>
# 145517: cdn.one.com.mt - benign_2312:unknown
# <class 'dict'>
# 240708: sioncwilt.ceredigion.sch.uk - benign_2312:unknown
# <class 'dict'>
# 405753: defi.equipment - benign_2312:unknown
# <class 'dict'>
# 517627: us-dc-03-14.cloudbackup.management - benign_2312:unknown
# <class 'dict'>
# 471674: web-app-assets.synap.ac - benign_2312:unknown
# <class 'dict'>
# 478024: ms-esports.wtf - benign_2312:unknown
# <class 'dict'>
# 421964: shop.nmrn.org.uk - benign_2312:unknown
# <class 'dict'>
# 220118: almazov.doctor - benign_2312:unknown
# <class 'dict'>
# 167840: ichhelfe.jetzt - benign_2312:unknown
# <class 'dict'>
# 105851: allendgreen.com - misp_2310:phishing
# <class 'dict'>
# 25898: ee-account-unlock.firebaseapp.com - phishing_since_2402:phishing
# <class 'dict'>
# 286206: velobaza.net.ua - benign_2312:unknown
# <class 'dict'>
# 238657: fuse.osaka.jp - benign_2312:unknown
# <class 'dict'>
# 546768: edge.xivo.solutions - benign_2312:unknown
# <class 'dict'>
# 521950: awqaf.gov.sa - benign_2312:unknown
# <class 'dict'>
# 116167: aura.stream.voidboost.cc - benign_2312:unknown
# <class 'dict'>
# 385692: dominios.co.ao - benign_2312:unknown
# <class 'dict'>
# 386135: mystical.garden - benign_2312:unknown
# <class 'dict'>
# 503343: klappe.hamburg - benign_2312:unknown
# <class 'dict'>
# 441546: s1.lematin.ma - benign_2312:unknown
# <class 'dict'>
# 496393: live6.bmd.gov.bd - benign_2312:unknown
# <class 'dict'>
# 520252: hell.ky - benign_2312:unknown
# <class 'dict'>
# 172290: inforpress.cv - benign_2312:unknown
# <class 'dict'>
# 51229: docs1-shared-0utlook.web.app - misp_2310:phishing
# <class 'dict'>
# 304374: galkotmun.gov.np - benign_2312:unknown
# <class 'dict'>
# 547614: connect.academics.education - benign_2312:unknown
# <class 'dict'>
# 384795: aei.archi - benign_2312:unknown
# <class 'dict'>
# 473524: seminolecounty.ada.support - benign_2312:unknown
# <class 'dict'>
# 340095: www4.um.edu.uy - benign_2312:unknown
# <class 'dict'>
# 117754: cdn-d.youplay.se - benign_2312:unknown
# <class 'dict'>
# 249097: beacon.tws.toyota.jp - benign_2312:unknown
# <class 'dict'>
# 133038: xn--e1akargdoe.xn--p1ai - benign_2312:unknown
# <class 'dict'>
# 427542: specialinfo.store - benign_2312:unknown
# <class 'dict'>
# 428837: rav.store - benign_2312:unknown
# <class 'dict'>
# 491343: northisland.ventures - benign_2312:unknown
# <class 'dict'>
# 73169: arsmtp000x0001.firebaseapp.com - misp_2310:phishing
# <class 'dict'>
# 131542: dellbatteryshop.com.my - benign_2312:unknown
# <class 'dict'>
# 535217: web.rubi.aplicatiuspin.cat - benign_2312:unknown
# <class 'dict'>
# 463875: epicovcharts.bii.a-star.edu.sg - benign_2312:unknown
# <class 'dict'>
# 540514: phoenix.org.ua - benign_2312:unknown
# <class 'dict'>
# 33743: anujsingh2003.github.io - phishing_since_2402:phishing
# <class 'dict'>
# 307352: sim.edu.sg - benign_2312:unknown
# <class 'dict'>
# 542958: certification-oea.ovh - benign_2312:unknown
# <class 'dict'>
# 556984: baccaratcenter.bet - benign_2312:unknown
# <class 'dict'>
# 432638: perthweddingcars.net.au - benign_2312:unknown
# <class 'dict'>
# 518737: tts.partners - benign_2312:unknown
# <class 'dict'>
# 328215: cover.nl.go.kr - benign_2312:unknown
# <class 'dict'>
# 401375: kirchhoff.hair - benign_2312:unknown
# <class 'dict'>
# 236795: voipack.fax.net.hk - benign_2312:unknown
# <class 'dict'>
# 310468: ipseoacavalcanti.edu.it - benign_2312:unknown
# <class 'dict'>
# 274018: centrodenutricion.mx - benign_2312:unknown
# <class 'dict'>
# 170633: alldom.kr.ua - benign_2312:unknown
# <class 'dict'>
# 401343: crsd.org.sa - benign_2312:unknown
# <class 'dict'>
# 438628: thewowstore.com.ph - benign_2312:unknown
# <class 'dict'>
# 55675: agencebp07.web.app - misp_2310:phishing
# <class 'dict'>
# 180071: camp2014.drupal.dn.ua - benign_2312:unknown
# <class 'dict'>
# 138206: manora.ma - benign_2312:unknown
# <class 'dict'>
# 381821: mbk.cv.ua - benign_2312:unknown
# <class 'dict'>
# 137512: img.onl - benign_2312:unknown
# <class 'dict'>
# 207917: latinomove.productions - benign_2312:unknown
# <class 'dict'>
# 192705: lronhubbard.rw - benign_2312:unknown
# <class 'dict'>
# 439791: tylee.tw - benign_2312:unknown
# <class 'dict'>
# 73644: mycomm-review.com - misp_2310:phishing
# <class 'dict'>
# 421606: s01.datoid.fun - benign_2312:unknown
# <class 'dict'>
# 377505: 9lo.rzeszow.pl - benign_2312:unknown
# <class 'dict'>
# 275323: images.isbn.nu - benign_2312:unknown
# <class 'dict'>
# 510770: dentist.directory - benign_2312:unknown
# <class 'dict'>
# 486137: yarrahills.vic.edu.au - benign_2312:unknown
# <class 'dict'>
# 245742: royalstore.com.in - benign_2312:unknown
# <class 'dict'>
# 535025: asdar.id - benign_2312:unknown
# <class 'dict'>
# 442598: jennygarrett.global - benign_2312:unknown
# <class 'dict'>
# 308038: ksbm.or.kr - benign_2312:unknown
# <class 'dict'>
# 398756: freelance.vlaanderen - benign_2312:unknown
# <class 'dict'>
# 50701: app-unsiwap.com - misp_2310:phishing
# <class 'dict'>
# 10322: fmbnc-acctservices.web.app - phishing_since_2402:phishing
# <class 'dict'>
# 414590: omegleporn.to - benign_2312:unknown
# <class 'dict'>
# 197909: godinton.kent.sch.uk - benign_2312:unknown
# <class 'dict'>
# 520010: alaska.xhamster.desi - benign_2312:unknown
# <class 'dict'>
# 68393: segundavlaonline.com - misp_2310:phishing
# <class 'dict'>
# 3938: notariadelosangeles.cl - phishing_since_2402:phishing
# <class 'dict'>
# 45641: ggyyt1.godaddysites.com - misp_2310:phishing
# <class 'dict'>
# 18492: bafkreifjwvbqp2kmqkodssmu6nzakvo7zdqdxqf4r2or6rle4yuuutkd2a.ipfs.infura-ipfs.io - phishing_since_2402:phishing
# <class 'dict'>
# 175981: cnt.xhamster.desi - benign_2312:unknown
# <class 'dict'>
# 549350: cp.vianet.com.np - benign_2312:unknown
# <class 'dict'>
# 305848: 85-90-246-82.40f09287913f45ae9ba01d68a3fcef20.plex.direct - benign_2312:unknown
# <class 'dict'>
# 163493: pers.uz.zgora.pl - benign_2312:unknown
# <class 'dict'>
# 316394: oulama.dz - benign_2312:unknown
# <class 'dict'>
# 463982: khanlex.mn - benign_2312:unknown
# <class 'dict'>
# 297540: letincelle.qc.ca - benign_2312:unknown
# <class 'dict'>
# 155073: motoart.kharkov.ua - benign_2312:unknown
# <class 'dict'>
# 172956: onlybylisa.jewelry - benign_2312:unknown
# <class 'dict'>
# 226064: paris.billet.flights - benign_2312:unknown
# <class 'dict'>
# 314346: penny.cool - benign_2312:unknown
# <class 'dict'>
# 201474: ve.solar - benign_2312:unknown
# <class 'dict'>
# 50955: metasupport1020340234023432.firebaseapp.com - misp_2310:phishing
# <class 'dict'>
# 340825: groby.cui.wroclaw.pl - benign_2312:unknown
# <class 'dict'>
# 439064: w.cncnnostalgic.buzz - benign_2312:unknown
# <class 'dict'>
# 179429: pacu.org.ph - benign_2312:unknown
# <class 'dict'>
# 334739: admission.kau.edu.sa - benign_2312:unknown
# <class 'dict'>
# 380282: alexgomez.tattoo - benign_2312:unknown
# <class 'dict'>
# 208603: fnbswaziland.co.sz - benign_2312:unknown
# <class 'dict'>
# 363757: image.opencms.storm.mg - benign_2312:unknown
# <class 'dict'>
# 20649: netflix-clone-6caff.web.app - phishing_since_2402:phishing
# <class 'dict'>
# 467146: andybay.ac.nz - benign_2312:unknown
# <class 'dict'>
# 370733: techradar.com.slc-208.van-qa.futureplc.engineering - benign_2312:unknown
# <class 'dict'>
# 560820: arquitetas.net.br - benign_2312:unknown
# <class 'dict'>
# 26139: krupa-motoryzacja.pl - phishing_since_2402:phishing
# <class 'dict'>
# 23610: usps.trckposts.top - phishing_since_2402:phishing
# <class 'dict'>
# 263785: zamosc.praca.gov.pl - benign_2312:unknown
# <class 'dict'>
# 152220: carreg-gwalch.cymru - benign_2312:unknown
# <class 'dict'>
# 249456: botcli.credit-agricole.fr - benign_2312:unknown
# <class 'dict'>
# 520456: idp.jxas.ac.cn - benign_2312:unknown
# <class 'dict'>
# 256847: eshop-czu-cz.translate.goog - benign_2312:unknown
# <class 'dict'>
# 225941: domnadjeziorem.mazury.pl - benign_2312:unknown
# <class 'dict'>
# 113150: anekdot.biz - benign_2312:unknown
# <class 'dict'>
# 498457: si-khatlon.tj - benign_2312:unknown
# <class 'dict'>
# 473361: mscaecon.hkbu.edu.hk - benign_2312:unknown
# <class 'dict'>
# 173278: pearlriver.lib.ms.us - benign_2312:unknown
# <class 'dict'>
# 352476: enpleinair.sm - benign_2312:unknown
# <class 'dict'>
# 541535: static.gem.gov.in - benign_2312:unknown
# <class 'dict'>
# 427160: mano.ku.lt - benign_2312:unknown
# <class 'dict'>
# 264737: varkom.hr - benign_2312:unknown
# <class 'dict'>
# 133044: webguide.nat.gov.tw - benign_2312:unknown
# <class 'dict'>
# 187830: woodside.aberdeen.sch.uk - benign_2312:unknown
# <class 'dict'>
# 248019: api.pmcaller.pl - benign_2312:unknown
# <class 'dict'>
# 434331: acyp.nsw.gov.au - benign_2312:unknown
# <class 'dict'>
# 6896: bafybeic23fbfzhe5gag6w2t2c7iulaxzcl5jytpw2ioja6kzt526533evm.ipfs.cf-ipfs.com - phishing_since_2402:phishing
# <class 'dict'>
# 98149: pub-459a57b7ba8f4e65ac9143b09c918569.r2.dev - misp_2310:phishing
# <class 'dict'>
# 119983: curtain.wtf - benign_2312:unknown
# <class 'dict'>
# 103274: fb-93ba1.firebaseapp.com - misp_2310:phishing
# <class 'dict'>
# 203032: e5.emprego.co.ao - benign_2312:unknown
# <class 'dict'>
# 202897: biblioteka.lebork.pl - benign_2312:unknown
# <class 'dict'>
# 138710: observices.wiz.money - benign_2312:unknown
# <class 'dict'>
# 513052: 71.ventures - benign_2312:unknown
# <class 'dict'>
# 3018: mxmoajs-github-csnvioze8-sowerby202s-projects.vercel.app - phishing_since_2402:phishing
# <class 'dict'>
# 343348: annonces.educarriere.ci - benign_2312:unknown
# <class 'dict'>
# 548403: status-api.apps.silver.devops.gov.bc.ca - benign_2312:unknown
# <class 'dict'>
# 195997: coecdn1.leme.hk.cn - benign_2312:unknown
# <class 'dict'>
# 30776: bnkid-bruker.firebaseapp.com - phishing_since_2402:phishing
# <class 'dict'>
# 554664: athlon.fit - benign_2312:unknown
# <class 'dict'>
# 347242: enterthebunker.webcam - benign_2312:unknown
# <class 'dict'>
# 292164: weblabs.tn - benign_2312:unknown
# <class 'dict'>
# 419413: blackstar.gg - benign_2312:unknown
# <class 'dict'>
# 195626: oaza.swidnica.pl - benign_2312:unknown
# <class 'dict'>
# 454228: lvm.bz - benign_2312:unknown
# <class 'dict'>
# 77674: ltaucardspontua119.z9.web.core.windows.net - misp_2310:phishing
# <class 'dict'>
# 249021: b.broadmaster.top - benign_2312:unknown
# <class 'dict'>
# 364967: ghostwrite.rip - benign_2312:unknown
# <class 'dict'>
# 434044: wilddiscoveries.co.ke - benign_2312:unknown
# <class 'dict'>
# 544354: panaretos.com.cy - benign_2312:unknown
# <class 'dict'>
# 462066: t.shows4.cfd - benign_2312:unknown
# <class 'dict'>
# 90514: 2930293884738299.hyperphp.com - misp_2310:phishing
# <class 'dict'>
# 339565: mail.orcon.net.nz - benign_2312:unknown
# <class 'dict'>
# 104941: appealeation-6e230.firebaseapp.com - misp_2310:phishing
# <class 'dict'>
# 117456: beeg.work - benign_2312:unknown
# <class 'dict'>
# 509256: doradztwo-podatkowe.szczecin.pl - benign_2312:unknown
# <class 'dict'>
# 379371: emm.cv.ua - benign_2312:unknown
# <class 'dict'>
# 21218: syst-mean.swanndvr.net - phishing_since_2402:phishing
# <class 'dict'>
# 320020: clt.vtc.edu.hk - benign_2312:unknown
# <class 'dict'>
# 455190: meeha.com.bd - benign_2312:unknown
# <class 'dict'>
# 531584: 6tv.by - benign_2312:unknown
# <class 'dict'>
# 143962: arakmu.ac.ir - benign_2312:unknown
# <class 'dict'>
# 328954: 13lik.city.kharkov.ua - benign_2312:unknown
# <class 'dict'>
# 499731: inmobiliariaguatemala.com.gt - benign_2312:unknown
# <class 'dict'>
# 488682: norwood.vic.edu.au - benign_2312:unknown
# <class 'dict'>
# 444139: ru.knutd.edu.ua - benign_2312:unknown
# <class 'dict'>
# 208973: orb.black - benign_2312:unknown
# <class 'dict'>
# 449370: ibay.com.bd - benign_2312:unknown
# <class 'dict'>
# 97934: sistefredco.liveblog365.com - misp_2310:phishing
# <class 'dict'>
# 190603: kosivart.if.ua - benign_2312:unknown
# <class 'dict'>
# 191239: xn--b1afyepcft1n.xn--j1amh - benign_2312:unknown
# <class 'dict'>
# 107642: bafkreidjybbaci7vaih2mnwvmxy34jez6palcdvzkmucc7qufxn7smmhny.ipfs.dweb.link - misp_2310:phishing
# <class 'dict'>
# 67553: aol-106740.weeblysite.com - misp_2310:phishing
# <class 'dict'>
# 370538: kinesitherapeute.tel - benign_2312:unknown
# <class 'dict'>
# 413404: js.rfp.fout.jp - benign_2312:unknown
# <class 'dict'>
# 86515: teotitahanuty.gq - misp_2310:phishing
# <class 'dict'>
# 103534: fb-4c444.firebaseapp.com - misp_2310:phishing
# <class 'dict'>
# 454369: speedynautical.ac.th - benign_2312:unknown
# <class 'dict'>
# 492956: gd.myway.science - benign_2312:unknown
# <class 'dict'>
# 396432: brainytrading.bo - benign_2312:unknown
# <class 'dict'>
# 366550: backpac.tf - benign_2312:unknown
# <class 'dict'>
# 532957: adrio.ee - benign_2312:unknown
# <class 'dict'>
# 140864: wiki.ideenhaus.wien - benign_2312:unknown
# <class 'dict'>
# 458738: isaacmaposa.co.zw - benign_2312:unknown
# <class 'dict'>
# 402851: multiconauditoria.srv.br - benign_2312:unknown
# <class 'dict'>
# 528034: sterautosleutels.nl - benign_2312:unknown
# <class 'dict'>
# 5430: shiny-meadow-251e.nsiaammnvotrse5636.workers.dev - phishing_since_2402:phishing
# <class 'dict'>
# 18954: hello-world-mute-truth-b189.rdratcliffe.workers.dev - phishing_since_2402:phishing
# <class 'dict'>
# 133674: bergstrom.bike - benign_2312:unknown
# <class 'dict'>
# 221904: orkhonvalley.gov.mn - benign_2312:unknown
# <class 'dict'>
# 571250: tami.beauty - benign_2312:unknown
# <class 'dict'>
# 438661: tsznewz.ng - benign_2312:unknown
# <class 'dict'>
# 510586: octopusgallery.mc - benign_2312:unknown
# <class 'dict'>
# 414763: p103-keyvalueservice.icloud.com.cn - benign_2312:unknown
# <class 'dict'>
# 105144: rawehitalixd.web.app - misp_2310:phishing
# <class 'dict'>
# 174071: worldskills.moscow - benign_2312:unknown
# <class 'dict'>
# 150211: ecda.gov.sg - benign_2312:unknown
# <class 'dict'>
# 320536: infinityhealth.ky - benign_2312:unknown
# <class 'dict'>
# 448451: recuperat-ion.com.es - benign_2312:unknown
# <class 'dict'>
# 69308: logingscreen.weebly.com - misp_2310:phishing
# <class 'dict'>
# 507832: mensch-sein.jetzt - benign_2312:unknown
# <class 'dict'>
# 501747: sel.migraciones.gob.pe - benign_2312:unknown
# <class 'dict'>
# 461813: fotokolej.waw.pl - benign_2312:unknown
# <class 'dict'>
# 378467: satellite.archi - benign_2312:unknown
# <class 'dict'>
# 65713: yahoo-104055.weeblysite.com - misp_2310:phishing
# <class 'dict'>
# 170138: rti.org.tw - benign_2312:unknown
# <class 'dict'>
# 150658: mcss.gov.on.ca - benign_2312:unknown
# <class 'dict'>
# 528842: wsb.edu.pl - benign_2312:unknown
# <class 'dict'>
# 538627: tolyatti--news-net.translate.goog - benign_2312:unknown
# <class 'dict'>
# 200909: repositorio.iniap.gob.ec - benign_2312:unknown
# <class 'dict'>
# 41517: case.fbpage-notifications.com - phishing_since_2402:phishing
# <class 'dict'>
# 386442: meinprofil5.clan.rip - benign_2312:unknown
# <class 'dict'>
# 273531: api.quadrillion.finance - benign_2312:unknown
# <class 'dict'>
# 317014: crp.photo - benign_2312:unknown
# <class 'dict'>
# 529653: asrebardsir.ir - benign_2312:unknown
# <class 'dict'>
# 443534: jinzaii.or.jp - benign_2312:unknown
# <class 'dict'>
# 10570: fpirasor.xyz - phishing_since_2402:phishing
# <class 'dict'>
# 325599: ttbc-hcm.gov.vn - benign_2312:unknown
# <class 'dict'>
# 21489: video-r.com - phishing_since_2402:phishing
# <class 'dict'>
# 265521: click.contenido.cencosud.cl - benign_2312:unknown
# <class 'dict'>
# 19243: allegrolokalnie.pl-specjalna-oferta72677.pl - phishing_since_2402:phishing
# <class 'dict'>
# 27946: alamrakamy.com - phishing_since_2402:phishing
# <class 'dict'>
# 553044: clarebennett.scot - benign_2312:unknown
# <class 'dict'>
# 510092: slet.je - benign_2312:unknown
# <class 'dict'>
# 286834: cluthadc.govt.nz - benign_2312:unknown
# <class 'dict'>
# 89515: bafybeih5wd6tejd6od3bzlyn4ngqj46r3yovcqndoffkfjyqoijxeweo4u.ipfs.cf-ipfs.com - misp_2310:phishing
# <class 'dict'>
# 283233: holidayhomerental.asia - benign_2312:unknown
# <class 'dict'>
# 185408: kashiwara.ed.jp - benign_2312:unknown
# <class 'dict'>
# 337484: dietaje.cool - benign_2312:unknown
# <class 'dict'>
# 155805: rhondasilver.house - benign_2312:unknown
# <class 'dict'>
# 225353: dam.gok.pk - benign_2312:unknown
# <class 'dict'>
# 194653: cesario.pro.br - benign_2312:unknown
# <class 'dict'>
# 45119: robertshepard35.wixsite.com - misp_2310:phishing
# <class 'dict'>
# 171327: charismatic.fund - benign_2312:unknown
# <class 'dict'>
# 51677: hvcu-sec.web.app - misp_2310:phishing
# <class 'dict'>
# 495527: sit.formosa.gob.ar - benign_2312:unknown
# <class 'dict'>
# 3203: sftvrepair.com - phishing_since_2402:phishing
# <class 'dict'>
# 275528: gbk.id - benign_2312:unknown
# <class 'dict'>
# 30377: ver-2ji.pages.dev - phishing_since_2402:phishing
# <class 'dict'>
# 523830: aramis.ad - benign_2312:unknown
# <class 'dict'>
# 280571: assets9.cre.ma - benign_2312:unknown
# <class 'dict'>
# 529140: 2.startimes.club - benign_2312:unknown
# <class 'dict'>
# 531238: sas.org.uk - benign_2312:unknown
# <class 'dict'>
# 62849: mychildsart.com.au - misp_2310:phishing
# <class 'dict'>
# 523913: icc.co.mz - benign_2312:unknown
# <class 'dict'>
# 423064: minkara.carview.co.jp - benign_2312:unknown
# <class 'dict'>
# 520165: winterbash.rip - benign_2312:unknown
# <class 'dict'>
# 6920: dhl.id9493905950035990.leadreport.info - phishing_since_2402:phishing
# <class 'dict'>
# 250737: cms-gpb.s3.nl-ams.scw.cloud - benign_2312:unknown
# <class 'dict'>
# 272315: serqqapisi.az - benign_2312:unknown
# <class 'dict'>
# 17216: uspd.usspav.top - phishing_since_2402:phishing
# <class 'dict'>
# 427763: norflexsrl.com.ar - benign_2312:unknown
# <class 'dict'>
# 176829: domar.zp.ua - benign_2312:unknown
# <class 'dict'>
# 504991: 262724204.zs-cardesignide.lat - benign_2312:unknown
# <class 'dict'>
# 176980: fhs.walton.k12.fl.us - benign_2312:unknown
# <class 'dict'>
# 136838: hbogm.meb.gov.tr - benign_2312:unknown
# <class 'dict'>
# 37013: bafybeifog2sh7xc7bngzeaean5q5cthf3putrihd75jc3s4nqdngb7amfu.ipfs.cf-ipfs.com - phishing_since_2402:phishing
# <class 'dict'>
# 528959: globalclassroom.us - benign_2312:unknown
# <class 'dict'>
# 227054: radiosucumbios.org.ec - benign_2312:unknown
# <class 'dict'>
# 205005: krapka.rv.ua - benign_2312:unknown
# <class 'dict'>
# 343483: nagad.express - benign_2312:unknown
# <class 'dict'>
# 209281: curvelandia.mt.gov.br - benign_2312:unknown
# <class 'dict'>
# 332457: informatyka.wmfi.uni.opole.pl - benign_2312:unknown
# <class 'dict'>
# 452199: battlefly.treasurehunt.lol - benign_2312:unknown
# <class 'dict'>
# 127195: pornhd.pics - benign_2312:unknown
# <class 'dict'>
# 136528: gg166.bet - benign_2312:unknown
# <class 'dict'>
# 354541: omanarbitration.om - benign_2312:unknown
# <class 'dict'>
# 74207: www.amazcecm-co-jp.amazaeon.j6021.cn - misp_2310:phishing
# <class 'dict'>
# 283004: ghjp090102.ghabc0823.tk - benign_2312:unknown
# <class 'dict'>
# 32800: www.dermage.be - phishing_since_2402:phishing
# <class 'dict'>
# 25504: sesi-fbdfde.apppp.my.id - phishing_since_2402:phishing
# <class 'dict'>
# 71634: euygy.square.site - misp_2310:phishing
# <class 'dict'>
# 254228: gfs208n149.userstorage.mega.co.nz - benign_2312:unknown
# <class 'dict'>
# 344457: bih.gov.hk - benign_2312:unknown
# <class 'dict'>
# 131000: www2.ncn.gov.pl - benign_2312:unknown
# <class 'dict'>
# 116432: beon.fun - benign_2312:unknown
# <class 'dict'>
# 238184: lavoro.regione.toscana.it - benign_2312:unknown
# <class 'dict'>
# 345640: landeskraftwerke.bayern - benign_2312:unknown
# <class 'dict'>
# 252784: emi.wmi.amu.edu.pl - benign_2312:unknown
# <class 'dict'>
# 78991: att-104792.weeblysite.com - misp_2310:phishing
# <class 'dict'>
# 247389: 29578.wintjaywolf.org - benign_2312:unknown
# <class 'dict'>
# 566098: archiwum-5pinz.wp.mil.pl - benign_2312:unknown
# <class 'dict'>
# 273039: yenihayat.az - benign_2312:unknown
# <class 'dict'>
# 561518: portalterritorial.dnp.gov.co - benign_2312:unknown
# <class 'dict'>
# 436935: btc.ph - benign_2312:unknown
# <class 'dict'>
# 103490: legendary-bavarois-6af920.netlify.app - misp_2310:phishing
# <class 'dict'>
# 175806: sharjahfc.gov.ae - benign_2312:unknown
# <class 'dict'>
# 482899: tanyllyn-nurseries.wales - benign_2312:unknown
# <class 'dict'>
# 559804: mynext.earth - benign_2312:unknown
# <class 'dict'>
# 299367: fatcats.africa - benign_2312:unknown
# <class 'dict'>
# 212574: augustinusbader.healthcare - benign_2312:unknown
# <class 'dict'>
# 446536: palet.academy - benign_2312:unknown
# <class 'dict'>
# 462692: xr.health - benign_2312:unknown
# <class 'dict'>
# 511802: aws.kibu.ac.ke - benign_2312:unknown
# <class 'dict'>
# 481369: kopetzki.law - benign_2312:unknown
# <class 'dict'>
# 410923: discountcode.dailymail.co.uk - benign_2312:unknown
# <class 'dict'>
# 194015: meblowy.salon - benign_2312:unknown
# <class 'dict'>
# 52127: dpd-dostvvka132.extelnist.cf - misp_2310:phishing
# <class 'dict'>
# 235390: fernielea.aberdeen.sch.uk - benign_2312:unknown
# <class 'dict'>
# 485589: neonconduit.game - benign_2312:unknown
# <class 'dict'>
# 136171: ecole-carmel-saint-joseph.ma - benign_2312:unknown
# <class 'dict'>
# 202224: blog.renjing.wang - benign_2312:unknown
# <class 'dict'>
# 59829: nvidia-drive1.site - misp_2310:phishing
# <class 'dict'>
# 476426: entrance.mec.gov.np - benign_2312:unknown
# <class 'dict'>
# 164344: bep.gov.pt - benign_2312:unknown
# <class 'dict'>
# 571619: hensel.family - benign_2312:unknown
# <class 'dict'>
# 319725: aumivi.immo - benign_2312:unknown
# <class 'dict'>
# 310962: worc.ky - benign_2312:unknown
# <class 'dict'>
# 209651: service-9549.fs.vg - benign_2312:unknown
# <class 'dict'>
# 299404: home.psu.ac.th - benign_2312:unknown
# <class 'dict'>
# 296800: unitrain.edu.vn - benign_2312:unknown
# <class 'dict'>
# 388418: tak.tik.edu.ee - benign_2312:unknown
# <class 'dict'>
# 297069: centrocultural.coop - benign_2312:unknown
# <class 'dict'>
# 89428: correos.fyi - misp_2310:phishing
# <class 'dict'>
# 196643: emploi.tg - benign_2312:unknown
# <class 'dict'>
# 572426: jet.mt - benign_2312:unknown
# <class 'dict'>
# 246791: bip.powiat.starachowice.pl - benign_2312:unknown
# <class 'dict'>
# 367273: loc.tax - benign_2312:unknown
# <class 'dict'>
# 182690: barrosmelo.edu.br - benign_2312:unknown
# <class 'dict'>
# 417438: worldcam.live - benign_2312:unknown
# <class 'dict'>
# 519897: termalhotelmartfu.inn.fan - benign_2312:unknown
# <class 'dict'>
# 407561: io.pro.br - benign_2312:unknown
# <class 'dict'>
# 310894: haute-savoie.gouv.fr - benign_2312:unknown
# <class 'dict'>
# 402935: icm.museum - benign_2312:unknown
# <class 'dict'>
# 356090: flordelis.com.pa - benign_2312:unknown
# <class 'dict'>
# 415366: pw.agh.edu.pl - benign_2312:unknown
# <class 'dict'>
# 568356: osgligorijepopov.edu.rs - benign_2312:unknown
# <class 'dict'>
# 389607: apartmani-mira.inn.fan - benign_2312:unknown
# <class 'dict'>
# 89483: bafybeieviz3qeowjtrou3mehzgfsghuwnyhqgtc5utqor6adkqnqea5yla.ipfs.cf-ipfs.com - misp_2310:phishing
# <class 'dict'>
# 120627: epiphany.masterworks.digital - benign_2312:unknown
# <class 'dict'>
# 108045: auta-eryk.pl - misp_2310:phishing
# <class 'dict'>
# 117217: blog.aegro.com.br - benign_2312:unknown
# <class 'dict'>
# 6679: long-king-63b8.rembidatinxrnae.workers.dev - phishing_since_2402:phishing
# <class 'dict'>
# 445636: c-bio.mine.utsunomiya-u.ac.jp - benign_2312:unknown
# <class 'dict'>
# 345330: eva.fcien.udelar.edu.uy - benign_2312:unknown
# <class 'dict'>
# 414091: moon-storage-delivery-s03.filemoon.to - benign_2312:unknown
# <class 'dict'>
# 554100: scratch.works - benign_2312:unknown
# <class 'dict'>
# 229371: hustle.college - benign_2312:unknown
# <class 'dict'>
# 147625: photography.org.nz - benign_2312:unknown
# <class 'dict'>
# 383818: facil.graphics - benign_2312:unknown
# <class 'dict'>
# 309524: soon-server-alb-production.soon.works - benign_2312:unknown
# <class 'dict'>
# 462523: clust.team - benign_2312:unknown
# <class 'dict'>
# 460749: slimkit.health - benign_2312:unknown
# <class 'dict'>
# 1593: dev-ahrocajenli.pantheonsite.io - phishing_since_2402:phishing
# <class 'dict'>
# 41765: wildcard.richardl.xyz - phishing_since_2402:phishing
# <class 'dict'>
# 560618: progest.com.pt - benign_2312:unknown
# <class 'dict'>
# 252101: doitnow.com.ua - benign_2312:unknown
# <class 'dict'>
# 15163: sky-103220.weeblysite.com - phishing_since_2402:phishing
# <class 'dict'>
# 22962: bafkreicxe4xmwrk5llolgwf7zve7l4azwvd6joah7vdtfbn7kfodhmi6yu.ipfs.nftstorage.link - phishing_since_2402:phishing
# <class 'dict'>
# 319762: thecloud.farm - benign_2312:unknown
# <class 'dict'>
# 234815: kogaya-oyaji.yokohama - benign_2312:unknown
# <class 'dict'>
# 130640: w2.vatican.va - benign_2312:unknown
# <class 'dict'>
# 58126: mitid-approve.20-203-169-150.cprapid.com - misp_2310:phishing
# <class 'dict'>
# 120887: eu.freesexvideos.porn - benign_2312:unknown
# <class 'dict'>
# 140290: sfr.kiev.ua - benign_2312:unknown
# <class 'dict'>
# 448604: wolfer.finance - benign_2312:unknown
# <class 'dict'>
# 333921: csi.codes - benign_2312:unknown
# <class 'dict'>
# 464322: s11.netu.ac - benign_2312:unknown
# <class 'dict'>
# 425896: capetrekking.co.za - benign_2312:unknown
# <class 'dict'>
# 85358: dhlexpress-pakets.de - misp_2310:phishing
# <class 'dict'>
# 217159: luciana.correa.nom.br - benign_2312:unknown
# <class 'dict'>
# 548598: support.visitkorea.or.kr - benign_2312:unknown
# <class 'dict'>
# 109073: mhfbpliebg.duckdns.org - misp_2310:phishing
# <class 'dict'>
# 403221: naturereserve.gi - benign_2312:unknown
# <class 'dict'>
# 29855: review-case-manage-1293132.web.app - phishing_since_2402:phishing
# <class 'dict'>
# 318623: gbdigital.consulting - benign_2312:unknown
# <class 'dict'>
# 208889: uk.popular.jewelry - benign_2312:unknown
# <class 'dict'>
# 127326: abigail.htu.tuwien.ac.at - benign_2312:unknown
# <class 'dict'>
# 229630: vko.kgd.gov.kz - benign_2312:unknown
# <class 'dict'>
# 545156: traxis-ngtv.cablenet.com.cy - benign_2312:unknown
# <class 'dict'>
# 381338: edsonespindola.arq.br - benign_2312:unknown
# <class 'dict'>
# 258490: matrix.dp15.us - benign_2312:unknown
# <class 'dict'>
# 84541: bafybeieklu7ry4oisqasugnkw3hj5gtctubnu5wlyd5mxz7pjy75jxruly.ipfs.cf-ipfs.com - misp_2310:phishing
# <class 'dict'>
# 98983: g9xsu6.csb.app - misp_2310:phishing
# <class 'dict'>
# 405866: 1d.muri.vg - benign_2312:unknown
# <class 'dict'>
# 353420: moretele.gov.za - benign_2312:unknown
# <class 'dict'>
# 239488: maristasico.edu.sv - benign_2312:unknown
# <class 'dict'>
# 215069: wegwijs.vlaanderen - benign_2312:unknown
# <class 'dict'>
# 195317: nova.te.ua - benign_2312:unknown
# <class 'dict'>
# 458767: bohemia.so - benign_2312:unknown
# <class 'dict'>
# 131157: webm.yespornplease.sexy - benign_2312:unknown
# <class 'dict'>
# 52177: exodus-walleti.com - misp_2310:phishing
# <class 'dict'>
# 54926: case1009601563058632012963.web.app - misp_2310:phishing
# <class 'dict'>
# 493512: games.nrw - benign_2312:unknown
# <class 'dict'>
# 397934: pointtur.tur.br - benign_2312:unknown
# <class 'dict'>
# 101509: www.lepetitclip.com - misp_2310:phishing
# <class 'dict'>
# 548884: nicefission.ga - benign_2312:unknown
# <class 'dict'>
# 130982: arabnews.pk - benign_2312:unknown
# <class 'dict'>
# 279334: healthon.tk - benign_2312:unknown
# <class 'dict'>
# 86015: reactprime505.firebaseapp.com - misp_2310:phishing
# <class 'dict'>
# 438805: wordpress.orsk.lasertaglsd.su - benign_2312:unknown
# <class 'dict'>
# 512138: shoponline.pet - benign_2312:unknown
# <class 'dict'>
# 23212: telstra-105889.weeblysite.com - phishing_since_2402:phishing
# <class 'dict'>
# 462185: bmt.or.kr - benign_2312:unknown
# <class 'dict'>
# 567347: soap2day.quest - benign_2312:unknown
# <class 'dict'>
# 34364: autogielda-matczak.pl - phishing_since_2402:phishing
# <class 'dict'>
# 390481: serlegal.com.sv - benign_2312:unknown
# <class 'dict'>
# 142944: 70b3a388cf1ef1b2f07ba7a9ec5c5642410db08d.i.twoinfo.work - benign_2312:unknown
# <class 'dict'>
# 454668: b2w-indonesia.or.id - benign_2312:unknown
# <class 'dict'>
# 81024: bafkreibus557bvm3n2zwvvxjxypsz2afyotq3q2vtttv2iqmcflc7k4zeq.ipfs.cf-ipfs.com - misp_2310:phishing
# <class 'dict'>
# 530694: rosap.ntl.bts.gov - benign_2312:unknown
# <class 'dict'>
# 225642: seadi.rr.gov.br - benign_2312:unknown
# <class 'dict'>
# 62551: opportunityextreme.com - misp_2310:phishing
# <class 'dict'>
# 532740: gabrica.cl - benign_2312:unknown
# <class 'dict'>
# 217227: gueen.makeup - benign_2312:unknown
# <class 'dict'>
# 533507: geoserver.nottinghamcity.gov.uk - benign_2312:unknown
# <class 'dict'>
# 424268: ws.eu.ocp.electrolux.one - benign_2312:unknown
# <class 'dict'>
# 15449: www.gmap-track.com - phishing_since_2402:phishing
# <class 'dict'>
# 274228: cu.jasa.name - benign_2312:unknown
# <class 'dict'>
# 159012: icfratellibandiera.edu.it - benign_2312:unknown
# <class 'dict'>
# 396337: fr.sportshub.fan - benign_2312:unknown
# <class 'dict'>
# 468948: eu-prod.cara.care - benign_2312:unknown
# <class 'dict'>
# 35556: domappcheckomeg31.firebaseapp.com - phishing_since_2402:phishing
# <class 'dict'>
# 306835: url6299.tandem.chat - benign_2312:unknown
# <class 'dict'>
# 394906: neighborhood.cab - benign_2312:unknown
# <class 'dict'>
# 357522: zdschool7.rv.ua - benign_2312:unknown
# <class 'dict'>
# 57405: seedify-dapp.com - misp_2310:phishing
# <class 'dict'>
# 283917: komentari.bosnainfo.ba - benign_2312:unknown
# <class 'dict'>
# 120821: data.cdc.gov - benign_2312:unknown
# <class 'dict'>
# 84065: ususcs.top - misp_2310:phishing
# <class 'dict'>
# 85321: gxxtnet.godaddysites.com - misp_2310:phishing
# <class 'dict'>
# 28809: telstra-109803.weeblysite.com - phishing_since_2402:phishing
# <class 'dict'>
# 119688: chaotic.half-shot.uk - benign_2312:unknown
# <class 'dict'>
# 5491: uspsidm.com - phishing_since_2402:phishing
# <class 'dict'>
# 199901: cpanel.ebyte.sale - benign_2312:unknown
# <class 'dict'>
# 223344: eng.kea.ne.kr - benign_2312:unknown
# <class 'dict'>
# 380749: susea.org.ph - benign_2312:unknown
# <class 'dict'>
# 512001: sna.com.tn - benign_2312:unknown
# <class 'dict'>
# 387772: atm.net.tr - benign_2312:unknown
# <class 'dict'>
# 405536: cryptoworld.college - benign_2312:unknown
# <class 'dict'>
# 81563: cvntrh.com - misp_2310:phishing
# <class 'dict'>
# 351803: win999bet.casino - benign_2312:unknown
# <class 'dict'>
# 458440: eriskaypony.scot - benign_2312:unknown
# <class 'dict'>
# 359694: ole.sex - benign_2312:unknown
# <class 'dict'>
# 343181: ifo.onchain.trade - benign_2312:unknown
# <class 'dict'>
# 256656: azfar9897.texy.info - benign_2312:unknown
# <class 'dict'>
# 417919: marieclaire.com.au - benign_2312:unknown
# <class 'dict'>
# 461121: magic.lol - benign_2312:unknown
# <class 'dict'>
# 456691: dl.pebble.host - benign_2312:unknown
# <class 'dict'>
# 389550: apc.net.ph - benign_2312:unknown
# <class 'dict'>
# 464092: member.moc.gov.tw - benign_2312:unknown
# <class 'dict'>
# 519268: xs.gy - benign_2312:unknown
# <class 'dict'>
# 506367: itc.net.vn - benign_2312:unknown
# <class 'dict'>
# 162320: igj.or.id - benign_2312:unknown
# <class 'dict'>
# 532874: poreklo.rs - benign_2312:unknown
# <class 'dict'>
# 425982: cdn16.vembz.one - benign_2312:unknown
# <class 'dict'>
# 376152: dedetizadoraem.eco.br - benign_2312:unknown
# <class 'dict'>
# 355758: auvillar.museum - benign_2312:unknown
# <class 'dict'>
# 568925: stv.kh.ua - benign_2312:unknown
# <class 'dict'>
# 72402: 129.226.210.78 - misp_2310:phishing
# <class 'dict'>
# 229106: trasparenza.asl.at.it - benign_2312:unknown
# <class 'dict'>
# 443744: jazb.academy - benign_2312:unknown
# <class 'dict'>
# 313726: fococontabilidade.net.br - benign_2312:unknown
# <class 'dict'>
# ...
# <class 'dict'>
# 353663: butternutcreek.golf - benign_2312:unknown
# <class 'dict'>
# 260676: qazsporttv.kz - benign_2312:unknown
# <class 'dict'>
# 74044: www.saisoaoard.co.jp.ukbkpc.top - misp_2310:phishing
# <class 'dict'>
# 402748: concha.date - benign_2312:unknown
# <class 'dict'>
# 230340: ojciecpio.kalisz.pl - benign_2312:unknown
# <class 'dict'>
# 24393: gosamba.in - phishing_since_2402:phishing
# <class 'dict'>
# 282641: exotic.co.th - benign_2312:unknown
# <class 'dict'>
# 372007: hchs.ed.jp - benign_2312:unknown
# <class 'dict'>
# 298715: business-consulting.berlin - benign_2312:unknown
# <class 'dict'>
# 36698: skywalker.infura-ipfs.io - phishing_since_2402:phishing
# <class 'dict'>
# 356577: nm.tj - benign_2312:unknown
# <class 'dict'>
# 127704: polka.academy - benign_2312:unknown
# <class 'dict'>
# 415282: profile.loona.dev - benign_2312:unknown
# <class 'dict'>
# 134231: bbb2.cooltools.education - benign_2312:unknown
# <class 'dict'>
# 146724: kerlarenov.bzh - benign_2312:unknown
# <class 'dict'>
# 417148: uknode32.shop - benign_2312:unknown
# <class 'dict'>
# 474196: adul.org.ar - benign_2312:unknown
# <class 'dict'>
# 25027: trackdomain.onelink.me - phishing_since_2402:phishing
# <class 'dict'>
# 384376: msj.syd.catholic.edu.au - benign_2312:unknown
# <class 'dict'>
# 485016: carer.org.hk - benign_2312:unknown
# <class 'dict'>
# 477298: publishinghub.international - benign_2312:unknown
# <class 'dict'>
# 178798: ar.weber - benign_2312:unknown
# <class 'dict'>
# 220929: b2b.miami - benign_2312:unknown
# <class 'dict'>
# 30813: allegrolokalnie.pl-oferta9242.pl - phishing_since_2402:phishing
# <class 'dict'>
# 417694: bml.gv.at - benign_2312:unknown
# <class 'dict'>
# 563943: sanmarti.com.mk - benign_2312:unknown
# <class 'dict'>
# 504273: tutordoctor.com.pa - benign_2312:unknown
# <class 'dict'>
# 240819: marketing.plumbing - benign_2312:unknown
# <class 'dict'>
# 277346: sadobe.falabella.com.co - benign_2312:unknown
# <class 'dict'>
# 352800: drew-and-amys.wedding - benign_2312:unknown
# <class 'dict'>
# 229951: hotels.td - benign_2312:unknown
# <class 'dict'>
# 165614: ptma.au - benign_2312:unknown
# <class 'dict'>
# 416236: stat.akharinkhabar.ir - benign_2312:unknown
# <class 'dict'>
# 79622: sign-in-att-100012.weeblysite.com - misp_2310:phishing
# <class 'dict'>
# 33088: chase-103084.weeblysite.com - phishing_since_2402:phishing
# <class 'dict'>
# 412370: gunnhildr-24-03.top - benign_2312:unknown
# <class 'dict'>
# 191312: nalog.gov.by - benign_2312:unknown
# <class 'dict'>
# 503725: maruia.school.nz - benign_2312:unknown
# <class 'dict'>
# 165480: ru.weber - benign_2312:unknown
# <class 'dict'>
# 31094: jprrpgfdlo.duckdns.org - phishing_since_2402:phishing
# <class 'dict'>
# 248416: api.nsbox.pl - benign_2312:unknown
# <class 'dict'>
# 302940: stpauls.br - benign_2312:unknown
# <class 'dict'>
# 31296: bt-internet-109329.weeblysite.com - phishing_since_2402:phishing
# <class 'dict'>
# 229644: sp6.kolobrzeg.pl - benign_2312:unknown
# <class 'dict'>
# 212155: roshan.info.np - benign_2312:unknown
# <class 'dict'>
# 160951: amber.international - benign_2312:unknown
# <class 'dict'>
# 240670: wellow.hants.sch.uk - benign_2312:unknown
# <class 'dict'>
# 115342: appability.inclusion.cc - benign_2312:unknown
# <class 'dict'>
# 474191: wss-31-171-212-57.bjn.vc - benign_2312:unknown
# <class 'dict'>
# 31110: bt-104743-105975.weeblysite.com - phishing_since_2402:phishing
# <class 'dict'>
# 412776: images.ipros.jp - benign_2312:unknown
# <class 'dict'>
# 200358: stats.sublime.security - benign_2312:unknown
# <class 'dict'>
# 210123: zhijin.wang - benign_2312:unknown
# <class 'dict'>
# 526842: la-tour.aprium-pharmacie.fr - benign_2312:unknown
# <class 'dict'>
# 232993: chauveau.nom.fr - benign_2312:unknown
# <class 'dict'>
# 2833: bt-105417.weeblysite.com - phishing_since_2402:phishing
# <class 'dict'>
# 53550: ups-serviceupdate.com - misp_2310:phishing
# <class 'dict'>
# 534860: w.healb10.buzz - benign_2312:unknown
# <class 'dict'>
# 72348: m-facebook-com-en.weebly.com - misp_2310:phishing
# <class 'dict'>
# 481030: mkdev.ar - benign_2312:unknown
# <class 'dict'>
# 12558: usps.posthelpnb.top - phishing_since_2402:phishing
# <class 'dict'>
# 548610: ticketing.events - benign_2312:unknown
# <class 'dict'>
# 6775: belsouthverifhdour8rnfedxde.webflow.io - phishing_since_2402:phishing
# <class 'dict'>
# 328202: contaudit.com.ro - benign_2312:unknown
# <class 'dict'>
# 494454: coaching-kraeutlein.jetzt - benign_2312:unknown
# <class 'dict'>
# 72033: aol-109802.weeblysite.com - misp_2310:phishing
# <class 'dict'>
# 2413: mryanwl9.wixsite.com - phishing_since_2402:phishing
# <class 'dict'>
# 9383: templat65sldh.myfreesites.net - phishing_since_2402:phishing
# <class 'dict'>
# 350107: speedtest.tel - benign_2312:unknown
# <class 'dict'>
# 161319: bestprice.dp.ua - benign_2312:unknown
# <class 'dict'>
# 184133: comune.calci.pi.it - benign_2312:unknown
# <class 'dict'>
# 284571: mojekonto.etoll.gov.pl - benign_2312:unknown
# <class 'dict'>
# 490199: ktd.gov.hk - benign_2312:unknown
# <class 'dict'>
# 178632: vieclamnhanh.net.vn - benign_2312:unknown
# <class 'dict'>
# 225273: e-shop.om.weber - benign_2312:unknown
# <class 'dict'>
# 147116: nxt.eco - benign_2312:unknown
# <class 'dict'>
# 272664: turan.az - benign_2312:unknown
# <class 'dict'>
# 98948: live120-gw-cu-pro554.web.app - misp_2310:phishing
# <class 'dict'>
# 244536: thuexe.pro.vn - benign_2312:unknown
# <class 'dict'>
# 463277: taranis.ag - benign_2312:unknown
# <class 'dict'>
# 125180: mail.eminingtti.ac.ke - benign_2312:unknown
# <class 'dict'>
# 204320: pref.miyagi.jp - benign_2312:unknown
# <class 'dict'>
# 505623: aidwatch.ps - benign_2312:unknown
# <class 'dict'>
# 20507: ususie.top - phishing_since_2402:phishing
# <class 'dict'>
# 353670: amantes.wedding - benign_2312:unknown
# <class 'dict'>
# 97207: resgatespontobb.com - misp_2310:phishing
# <class 'dict'>
# 192632: chia.tt - benign_2312:unknown
# <class 'dict'>
# 17542: bov-mt.web.app - phishing_since_2402:phishing
# <class 'dict'>
# 554604: sahabet.health - benign_2312:unknown
# <class 'dict'>
# 347763: ilhasolteira.sp.gov.br - benign_2312:unknown
# <class 'dict'>
# 373886: immeln.camp - benign_2312:unknown
# <class 'dict'>
# 376324: agl.co.mz - benign_2312:unknown
# <class 'dict'>
# 333732: ge.jobs - benign_2312:unknown
# <class 'dict'>
# 547728: torik4.ulakbim.gov.tr - benign_2312:unknown
# <class 'dict'>
# 79617: att-106843.weeblysite.com - misp_2310:phishing
# <class 'dict'>
# 319069: i.nyah.moe - benign_2312:unknown
# <class 'dict'>
# 527306: p2-3.pvvstream.pro - benign_2312:unknown
# <class 'dict'>
# 513116: transportescallejas.com.sv - benign_2312:unknown
# <class 'dict'>
# 472480: hemuat.hlth.gov.bc.ca - benign_2312:unknown
# <class 'dict'>
# 225043: pngmet.gov.pg - benign_2312:unknown
# <class 'dict'>
# 271840: dubaiairshow.aero - benign_2312:unknown
# <class 'dict'>
# 322807: thumb.fakeface.rest - benign_2312:unknown
# <class 'dict'>
# 548106: es.nccu.edu.tw - benign_2312:unknown
# <class 'dict'>
# 453067: amo.on.ca - benign_2312:unknown
# <class 'dict'>
# 509791: jungwon.re.kr - benign_2312:unknown
# <class 'dict'>
# 492949: khoksaad.go.th - benign_2312:unknown
# <class 'dict'>
# 172433: joomloc.fr.nf - benign_2312:unknown
# <class 'dict'>
# 115089: app.ssdsp.smt.docomo.ne.jp - benign_2312:unknown
# <class 'dict'>
# 177375: komun.te.ua - benign_2312:unknown
# <class 'dict'>
# 470810: lynx.care - benign_2312:unknown
# <class 'dict'>
# 285948: southstardrug.com.ph - benign_2312:unknown
# <class 'dict'>
# 124533: lovely.dating - benign_2312:unknown
# <class 'dict'>
# 244859: rutlish.merton.sch.uk - benign_2312:unknown
# <class 'dict'>
# 403275: fedi.midnight.miami - benign_2312:unknown
# <class 'dict'>
# 30036: dschindewolf.myportfolio.com - phishing_since_2402:phishing
# <class 'dict'>
# 146488: fuze.ng - benign_2312:unknown
# <class 'dict'>
# 288083: ee-town.sakura.ne.jp - benign_2312:unknown
# <class 'dict'>
# 62062: test-new-form-1929299422.firebaseapp.com - misp_2310:phishing
# <class 'dict'>
# 367632: ethicscommissioner.ab.ca - benign_2312:unknown
# <class 'dict'>
# 484424: nighttrader.exchange - benign_2312:unknown
# <class 'dict'>
# 441584: tnsic.gov.in - benign_2312:unknown
# <class 'dict'>
# 493194: ruyton.vic.edu.au - benign_2312:unknown
# <class 'dict'>
# 375699: nikaia-rentis.gov.gr - benign_2312:unknown
# <class 'dict'>
# 107791: comitcantomemsetingsb.vercel.app - misp_2310:phishing
# <class 'dict'>
# 393903: horas88.vin - benign_2312:unknown
# <class 'dict'>
# 384628: 52yh.wang - benign_2312:unknown
# <class 'dict'>
# 507672: aloha24.com.pa - benign_2312:unknown
# <class 'dict'>
# 364965: buildpress.com.ro - benign_2312:unknown
# <class 'dict'>
# 191513: popcorn.bigbob.tm - benign_2312:unknown
# <class 'dict'>
# 331565: juicer.lime.bike - benign_2312:unknown
# <class 'dict'>
# 23465: bafybeibjd5tzygmnqvu4stuxs5iyk4uxuolkpf3hcbfvyi2z6o4poyq7ka.ipfs.cf-ipfs.com - phishing_since_2402:phishing
# <class 'dict'>
# 315586: dev.livingroom.health - benign_2312:unknown
# <class 'dict'>
# 411396: ernest.essec.edu - benign_2312:unknown
# <class 'dict'>
# 241559: sve.ordre.medecin.fr - benign_2312:unknown
# <class 'dict'>
# 447591: 226ers.com.pe - benign_2312:unknown
# <class 'dict'>
# 68188: bafybeids7dswfdtvuosh44ln3fpq262y3uttoheyik7rs4i3j2ftnnexha.ipfs.dweb.link - misp_2310:phishing
# <class 'dict'>
# 514321: izabellagolousheva.page.tl - benign_2312:unknown
# <class 'dict'>
# 18176: test-pages-website-5cz.pages.dev - phishing_since_2402:phishing
# <class 'dict'>
# 194409: banqueentreprise.bnpparibas - benign_2312:unknown
# <class 'dict'>
# 446883: bpcj.or.jp - benign_2312:unknown
# <class 'dict'>
# 421436: piktv.pik.bg - benign_2312:unknown
# <class 'dict'>
# 69472: kitchenexpress.co.za - misp_2310:phishing
# <class 'dict'>
# 317463: mift.org.my - benign_2312:unknown
# <class 'dict'>
# 237255: iba.org.zm - benign_2312:unknown
# <class 'dict'>
# 419309: 2xu.shop - benign_2312:unknown
# <class 'dict'>
# 390044: element.rzeszow.pl - benign_2312:unknown
# <class 'dict'>
# 57074: bloccapagamentisospetti.com - misp_2310:phishing
# <class 'dict'>
# 189280: zs3.rybnik.pl - benign_2312:unknown
# <class 'dict'>
# 142803: pixieminds.com.co - benign_2312:unknown
# <class 'dict'>
# 210081: jrubzp.hnlj.tv.tr - benign_2312:unknown
# <class 'dict'>
# 562936: alhadidi.coach - benign_2312:unknown
# <class 'dict'>
# 76538: dev-alertaitaupy.pantheonsite.io - misp_2310:phishing
# <class 'dict'>
# 557204: gravita.com.sa - benign_2312:unknown
# <class 'dict'>
# 190796: tucujuris.tjap.jus.br - benign_2312:unknown
# <class 'dict'>
# 383628: personalshopper.gt - benign_2312:unknown
# <class 'dict'>
# 439274: bio-active.co.th - benign_2312:unknown
# <class 'dict'>
# 87408: neatw.cfd - misp_2310:phishing
# <class 'dict'>
# 157886: www3.dramacool.cm - benign_2312:unknown
# <class 'dict'>
# 341284: bg42.ciakaloo.cf - benign_2312:unknown
# <class 'dict'>
# 104834: reply-b5856.web.app - misp_2310:phishing
# <class 'dict'>
# 351529: fabianschmidt.clothing - benign_2312:unknown
# <class 'dict'>
# 346906: tenderlinksschool.org.ng - benign_2312:unknown
# <class 'dict'>
# 201458: mbo.sensebank.kyiv.ua - benign_2312:unknown
# <class 'dict'>
# 260649: static.robtv.be - benign_2312:unknown
# <class 'dict'>
# 336155: majms.alkafeel.edu.iq - benign_2312:unknown
# <class 'dict'>
# 309763: rieckmann.works - benign_2312:unknown
# <class 'dict'>
# 107932: epost-d4534.web.app - misp_2310:phishing
# <class 'dict'>
# 400632: colquiri.gob.bo - benign_2312:unknown
# <class 'dict'>
# 95478: meta-business-case-4c0ac.web.app - misp_2310:phishing
# <class 'dict'>
# 241875: comune.senigallia.an.it - benign_2312:unknown
# <class 'dict'>
# 36952: bill-info-nz.com - phishing_since_2402:phishing
# <class 'dict'>
# 414480: nsp-edge-southwest2-drcn.cloud.huawei.com.cn - benign_2312:unknown
# <class 'dict'>
# 118328: cdncozyvideogalleryn.addons.business - benign_2312:unknown
# <class 'dict'>
# 147335: maschek.industries - benign_2312:unknown
# <class 'dict'>
# 537767: sa.uasm.md - benign_2312:unknown
# <class 'dict'>
# 341822: ha.edu.sa - benign_2312:unknown
# <class 'dict'>
# 431842: learngeorgian.ge - benign_2312:unknown
# <class 'dict'>
# 23016: identifiez-vous-44.hubside.fr - phishing_since_2402:phishing
# <class 'dict'>
# 442935: eng.inha.ac.kr - benign_2312:unknown
# <class 'dict'>
# 560700: de-gruyter.onlyfy.jobs - benign_2312:unknown
# <class 'dict'>
# 281646: climatedetectives.esa.int - benign_2312:unknown
# <class 'dict'>
# 354912: robyn.coach - benign_2312:unknown
# <class 'dict'>
# 138040: lab.cafe - benign_2312:unknown
# <class 'dict'>
# 135582: designertools.baars.design - benign_2312:unknown
# <class 'dict'>
# 246081: hcs.gov.ly - benign_2312:unknown
# <class 'dict'>
# 381599: ipip.pe.kr - benign_2312:unknown
# <class 'dict'>
# 185113: cdm.edu.eg - benign_2312:unknown
# <class 'dict'>
# 349112: cityrepair.au - benign_2312:unknown
# <class 'dict'>
# 249082: badge.dimensions.ai - benign_2312:unknown
# <class 'dict'>
# 165079: cobus.com.ec - benign_2312:unknown
# <class 'dict'>
# 236135: library.crimea.ua - benign_2312:unknown
# <class 'dict'>
# 208967: hexbachtal.ruhr - benign_2312:unknown
# <class 'dict'>
# 118244: cdn.skypack.dev - benign_2312:unknown
# <class 'dict'>
# 466829: time.hauca.win - benign_2312:unknown
# <class 'dict'>
# 541580: sv34.emcdnjsnf.tk - benign_2312:unknown
# <class 'dict'>
# 58856: uaso11.z13.web.core.windows.net - misp_2310:phishing
# <class 'dict'>
# 542160: steininger.st - benign_2312:unknown
# <class 'dict'>
# 489875: pad.cm - benign_2312:unknown
# <class 'dict'>
# 145881: ggm.com.pe - benign_2312:unknown
# <class 'dict'>
# 515096: get.1tap.tax - benign_2312:unknown
# <class 'dict'>
# 145283: cleanup.pictures - benign_2312:unknown
# <class 'dict'>
# 54600: authenticate-0oxsoxauthe.pages.dev - misp_2310:phishing
# <class 'dict'>
# 149962: canoe.film - benign_2312:unknown
# <class 'dict'>
# 386601: roads.org.mk - benign_2312:unknown
# <class 'dict'>
# 363553: ijs.frl - benign_2312:unknown
# <class 'dict'>
# 399073: eod.um.edu.mo - benign_2312:unknown
# <class 'dict'>
# 128372: research.bond.edu.au - benign_2312:unknown
# <class 'dict'>
# 330632: haugiang.gov.vn - benign_2312:unknown
# <class 'dict'>
# 530255: jfa.no - benign_2312:unknown
# <class 'dict'>
# 269360: research.x513.stream - benign_2312:unknown
# <class 'dict'>
# 106750: bafkreifcuub2sbck7oz5342ibbnaemodbnje3pwsl7m33eeo2tr4bxi7iu.ipfs.nftstorage.link - misp_2310:phishing
# <class 'dict'>
# 154041: img.scubatribe.reviews - benign_2312:unknown
# <class 'dict'>
# 352621: sollatekghana.com.gh - benign_2312:unknown
# <class 'dict'>
# 312840: fundaler.org.ar - benign_2312:unknown
# <class 'dict'>
# 555327: mc156.bet - benign_2312:unknown
# <class 'dict'>
# 211983: cialux.construction - benign_2312:unknown
# <class 'dict'>
# 54729: switzapps.blogspot.com - misp_2310:phishing
# <class 'dict'>
# 157709: vsp18.kmk.net.tr - benign_2312:unknown
# <class 'dict'>
# 4139: mercadolivre2022.blogspot.com - phishing_since_2402:phishing
# <class 'dict'>
# 559317: stateofthenation.co.zw - benign_2312:unknown
# <class 'dict'>
# 123803: itr-links.stackoverflow.email - benign_2312:unknown
# <class 'dict'>
# 570028: flisan.fo - benign_2312:unknown
# <class 'dict'>
# 512205: kipee.re.kr - benign_2312:unknown
# <class 'dict'>
# 168801: connect.services.global.ntt - benign_2312:unknown
# <class 'dict'>
# 101519: bafybeihlngz6h6zd2jhgg45dr2egr6qboid5bjyul6jzhszk57hcqexi44.ipfs.cf-ipfs.com - misp_2310:phishing
# <class 'dict'>
# 49040: gigmemfont.sisten45.repl.co - misp_2310:phishing
# <class 'dict'>
# 169329: faus.international - benign_2312:unknown
# <class 'dict'>
# 102882: usps.com.sopackeges.top - misp_2310:phishing
# <class 'dict'>
# 303739: aiml.events - benign_2312:unknown
# <class 'dict'>
# 114532: 404content.bm.digital - benign_2312:unknown
# <class 'dict'>
# 340867: lib-u4mtrqlkuycwig2ea7fce2q6.mountain.pm - benign_2312:unknown
# <class 'dict'>
# 385980: diflucan.gives - benign_2312:unknown
# <class 'dict'>
# 562392: everfield.software - benign_2312:unknown
# <class 'dict'>
# 367845: liveedge195.dmc.nico - benign_2312:unknown
# <class 'dict'>
# 58901: deco19.co.uk - misp_2310:phishing
# <class 'dict'>
# 452090: ahuntsic.cssdm.gouv.qc.ca - benign_2312:unknown
# <class 'dict'>
# 129790: srv12.y2mate.is - benign_2312:unknown
# <class 'dict'>
# 473941: epccajica.gov.co - benign_2312:unknown
# <class 'dict'>
# 135795: devui.design - benign_2312:unknown
# <class 'dict'>
# 54013: document-project-june.voicee-love.workers.dev - misp_2310:phishing
# <class 'dict'>
# 522556: mni.1slogir.vg - benign_2312:unknown
# <class 'dict'>
# 302846: monteazul.com.pe - benign_2312:unknown
# <class 'dict'>
# 109903: kaducollect.com - misp_2310:phishing
# <class 'dict'>
# 156130: search-bcarchives.royalbcmuseum.bc.ca - benign_2312:unknown
# <class 'dict'>
# 432252: n.cngunadvised.buzz - benign_2312:unknown
# <class 'dict'>

# %% [markdown]
# # Testing success on the sample dataset

# %%
import pandas as pd
import torch
import torch.nn.functional as F
import numpy as np
import math
from preprocessor import Preprocessor
from models.phishing_cnn_net import Net  # Ensure the model definition is available in models.py or adjust import accordingly

# Function to calculate the next perfect square greater than a given number
def next_perfect_square(n):
    next_square = math.ceil(n**0.5)**2
    return next_square

# Load the test dataset
test_dataset = 'testdata/sample.parquet'
pp = Preprocessor()
domain_data = pd.read_parquet(test_dataset)
feature_size = domain_data.shape[1] - 2  # -2 = Domain and Label

# Calculate the desired size for padding
desired_size = next_perfect_square(feature_size)
side_size = int(desired_size**0.5)
print(side_size)

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

state_dict = torch.load('models/phishing_cnn_model.pth')

# Initialize the model and load the state dict
model = Net(side_size).to(device)
model.load_state_dict(state_dict)
model.eval()

# Initialize counters for predictions
prediction_ok = 0
prediction_wrong = 0

fp = 0
fn = 0

tp = 0
tn = 0

# Iterate through each row in the dataset
for index, row in domain_data.iterrows():
    domain_name = row['domain_name']
    original_label = row['label']
    
    feature_vector = pd.DataFrame([row])
    feature_vector.drop(columns=['domain_name', 'label'], inplace=True)
    # print shape of feature_vector

    
    preprocessed_data = pp.NDF(feature_vector, 'phishing')
    # print shape of preprocessed_data['features']
    data_tensor = torch.tensor(preprocessed_data['features'], dtype=torch.float32)
    feature_size = data_tensor.shape[1]
    desired_size = next_perfect_square(feature_size)
    padding = desired_size - feature_size
    
    if padding > 0:
        data_tensor_padded = F.pad(data_tensor, (0, padding), 'constant', 0)
    else:
        data_tensor_padded = data_tensor
    
    side_size = int(np.sqrt(desired_size))
    data_tensor_reshaped = data_tensor_padded.view(-1, 1, side_size, side_size)
    data_tensor_reshaped = data_tensor_reshaped.to(device)

    with torch.no_grad():
        outputs = model(data_tensor_reshaped)
        probabilities = F.softmax(outputs, dim=1)
        probabilities_np = probabilities.detach().cpu().numpy()
        probabilities_np_rounded = np.round(probabilities_np, decimals=3)

        _, predicted = torch.max(outputs, 1)
        predicted_np = predicted.detach().cpu().numpy()
    
    # Corrected label assignment
    predicted_label = "MALIGN" if predicted_np[0] > 0.5 else "BENIGN"
    result = "WRONG"
    
    if (original_label.startswith("benign") and predicted_label == "BENIGN") or (original_label.startswith("malign") or original_label.startswith("misp") or original_label.startswith("phish") and predicted_label == "MALIGN"):
        result = "OK"
        prediction_ok += 1
        if predicted_label == "BENIGN":
            tn += 1
        elif predicted_label == "MALIGN":
            tp += 1
    else:
        prediction_wrong += 1
        if predicted_label == "BENIGN":
            fp += 1
        elif predicted_label == "MALIGN":
            fn += 1

    # print(f"Result: {result}")
    # print(f"Domain: {domain_name}")
    # print(f"Original Label: {original_label}")
    # print(f"Predicted Label: {predicted_label}")
    # print(f"Probabilities: {probabilities_np_rounded}")
    # print('-' * 50)

# compute f1 score
precision = tp / (tp + fp)
recall = tp / (tp + fn)
f1 = 2 * (precision * recall) / (precision + recall)
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Total OK Predictions: {prediction_ok}")
print(f"Total WRONG Predictions: {prediction_wrong}")
print(f"Accuracy Ratio: {prediction_ok / (prediction_ok + prediction_wrong):.2f}")
# Out:
# 14
# CNN model created
# Precision: 0.78
# Recall: 1.00
# F1 Score: 0.88
# Total OK Predictions: 967
# Total WRONG Predictions: 33
# Accuracy Ratio: 0.97
