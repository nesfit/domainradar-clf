# %%
import os

# Function to change to the parent directory
def change_to_parent_directory():
    # Check if the directory has already been changed
    if not os.environ.get('DIR_CHANGED'):
            current_dir = os.path.dirname(os.path.abspath(__file__))
        except NameError:
            current_dir = os.getcwd()
        parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
        os.chdir(parent_dir)
        os.environ['DIR_CHANGED'] = '1'
        print(f"Current working directory changed to: {os.getcwd()}")
    else:
        print("Directory has already been changed.")

# Call the function to change the working directory
change_to_parent_directory()
# Out:
# Current working directory changed to: /home/ihranicky/git

# %% [markdown]
# # Optional - Create a testing parquet

# %%
create_test_parquet = True

if create_test_parquet:
    import pandas as pd
    import numpy as np
    
    # List of input Parquet files
    input_files = [
        'testdata/misp_2402.parquet',
        'testdata/umbrella_benign_FINISHED.parquet'
    ]
    
    # Number of rows to select
    n_rows = 100
    
    # Read all Parquet files into a single DataFrame
    dataframes = [pd.read_parquet(file) for file in input_files]
    combined_df = pd.concat(dataframes, ignore_index=True)
    
    # Randomly select n_rows rows from the combined DataFrame
    selected_rows = combined_df.sample(n=n_rows, random_state=1)  # random_state for reproducibility
    
    # Save the selected rows to a new Parquet file
    selected_rows.to_parquet('testdata/sample.parquet')
    
    # Display the selected rows
    print(selected_rows)
# Out:
#                                  domain_name                         label  \
# 259954                        p24.dynect.net           benign_2310:unknown
# 358356                    policy.revasia.com           benign_2310:unknown
# 258589                     investvoyager.com           benign_2310:unknown
# 331248                             foxtv.com           benign_2310:unknown
# 59056                              griml.com            misp_2310:phishing
# ...                                      ...                           ...
# 311535  ci-bfp.aws-stsd.capitalonegslbex.com           benign_2310:unknown
# 23748               maliyeistrgov-tr5319.com  phishing_since_2402:phishing
# 173682                          ithinkfi.org           benign_2310:unknown
# 138127                       tags.feedad.com           benign_2310:unknown
# 133477    edge-038.ussea3.icloud-content.com           benign_2310:unknown
#
#         dns_has_dnskey  dns_A_count  dns_AAAA_count  dns_MX_count  \
# 259954             0.0            0               0             0
# 358356             0.0            2               2             0
# 258589             1.0            4               8             5
# 331248             1.0            0               0             2
# 59056              0.0            1               0             2
# ...                ...          ...             ...           ...
# 311535             0.0            4               0             0
# 23748              1.0            0               0             0
# 173682             0.0            1               0             1
# 138127             0.0            1               0             0
# 133477             0.0            0               0             0
#
#         dns_NS_count  dns_TXT_count  dns_SOA_count  dns_CNAME_count  ...  \
# 259954             0              0              0                0  ...
# 358356             0              0              0                0  ...
# 258589             2             11              1                0  ...
# 331248             8              7              1                0  ...
# 59056              2              1              1                0  ...
# ...              ...            ...            ...              ...  ...
# 311535             0              0              0                0  ...
# 23748              0              0              0                0  ...
# 173682             2              6              1                0  ...
# 138127             0              1              0                0  ...
# 133477             0              0              0                1  ...
#
#         rdap_ip_v4_count  rdap_ip_v6_count  rdap_ip_shortest_v4_prefix_len  \
# 259954                 0                 0                               0
# 358356                 2                 2                              12
# 258589                14                18                              13
# 331248                10                 0                              17
# 59056                  8                 5                              13
# ...                  ...               ...                             ...
# 311535                 4                 0                              17
# 23748                  0                 0                               0
# 173682                 9                 6                              11
# 138127                 1                 0                              10
# 133477                 1                 1                               8
#
#         rdap_ip_longest_v4_prefix_len  rdap_ip_shortest_v6_prefix_len  \
# 259954                              0                               0
# 358356                             13                              32
# 258589                             18                              28
# 331248                             23                               0
# 59056                              24                              32
# ...                               ...                             ...
# 311535                             17                               0
# 23748                               0                               0
# 173682                             20                              32
# 138127                             10                               0
# 133477                              8                              32
#
#         rdap_ip_longest_v6_prefix_len  rdap_ip_avg_admin_name_len  \
# 259954                              0                    0.000000
# 358356                             32                    5.000000
# 258589                             37                    9.187500
# 331248                              0                   11.600000
# 59056                              32                   12.266667
# ...                               ...                         ...
# 311535                              0                   13.000000
# 23748                               0                    0.000000
# 173682                             32                   11.533333
# 138127                              0                   10.000000
# 133477                             32                   18.000000
#
#         rdap_ip_avg_admin_name_entropy  rdap_ip_avg_admin_email_len  \
# 259954                        0.000000                     0.000000
# 358356                        0.464386                    18.000000
# 258589                        0.254866                    17.125000
# 331248                        0.275148                    20.400000
# 59056                         0.272092                    14.533333
# ...                                ...                          ...
# 311535                        0.249146                    23.000000
# 23748                         0.000000                     0.000000
# 173682                        0.293389                    17.200000
# 138127                        0.292193                    23.000000
# 133477                        0.204641                    23.000000
#
#         rdap_ip_avg_admin_email_entropy
# 259954                         0.000000
# 358356                         0.198468
# 258589                         0.137761
# 331248                         0.171775
# 59056                          0.185015
# ...                                 ...
# 311535                         0.149881
# 23748                          0.000000
# 173682                         0.159797
# 138127                         0.157442
# 133477                         0.172565
#
# [100 rows x 178 columns]

# %% [markdown]
# # Make a test run of conversion into NDF

# %%
import pandas as pd
from preprocessor import Preprocessor

test_dataset = 'testdata/sample.parquet'

pp = Preprocessor()

domain_data = pd.read_parquet(test_dataset)

for index, row in domain_data.iterrows():
    domain_name = row['domain_name']
    original_label = row['label']
    
    print(f"{index}: {domain_name} - {original_label}")
    
    feature_vector = pd.DataFrame([row])
    feature_vector.drop(columns=['domain_name', 'label'], inplace=True)
    
    ndf = pp.NDF(feature_vector, 'phishing')
    print(type(ndf))
    print(ndf)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 6
#       2 from preprocessor import Preprocessor
#       4 test_dataset = 'testdata/sample.parquet'
# ----> 6 pp = Preprocessor()
#       8 domain_data = pd.read_parquet(test_dataset)
#      10 for index, row in domain_data.iterrows():
#
# File ~/git/domainradar-clf/classifiers/preprocessor.py:29, in Preprocessor.__init__(self)
#      27 def __init__(self):
#      28     self.stored = {'dga': dict(), 'phishing': dict(), 'malware': dict()}
# ---> 29     self.stored["dga"]["scaler"] = joblib.load('boundaries/dga_scaler.joblib')
#      30     self.stored["dga"]["outliers"] = joblib.load('boundaries/dga_outliers.joblib')
#      31     self.stored["phishing"]["scaler"] = joblib.load('boundaries/phishing_scaler.joblib')
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'boundaries/dga_scaler.joblib'

# %% [markdown]
# # Testing success on the sample dataset

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import math
from preprocessor import Preprocessor

# Function to calculate the next perfect square greater than a given number
def next_perfect_square(n):
    next_square = math.ceil(n**0.5)**2
    return next_square

test_dataset = 'testdata/sample.parquet'
pp = Preprocessor()

domain_data = pd.read_parquet(test_dataset)
feature_size = domain_data.shape[1] - 2  # -2 = Domain and Label

desired_size = next_perfect_square(feature_size)  # Next perfect square
side_size = int(desired_size**0.5)

class Net(nn.Module):
    def __init__(self, side_size):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 256, 3, 1)
        self.dropout = nn.Dropout(0.1)
        self.fc1 = nn.Linear(256 * (side_size-4)**2, 1024)
        self.fc2 = nn.Linear(1024, 1024)
        self.fc3 = nn.Linear(1024, 1024)
        self.fc4 = nn.Linear(1024, 512)
        self.fc5 = nn.Linear(512, 2)
        print("CNN model created")

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.conv2(x))
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        return self.fc5(x)

# Load the trained CNN model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = torch.load('models/phishing_cnn_model.pth', map_location=device)
model = model.to(device)
model.eval()


for index, row in domain_data.iterrows():
    domain_name = row['domain_name']
    original_label = row['label']
    
    feature_vector = pd.DataFrame([row])
    feature_vector.drop(columns=['domain_name', 'label'], inplace=True)
    
    preprocessed_data = pp.NDF(feature_vector, 'phishing')

    data_tensor = preprocessed_data['features']
    feature_size = data_tensor.shape[1]
    desired_size = next_perfect_square(feature_size)
    padding = desired_size - feature_size
    if padding > 0:
        data_tensor_padded = F.pad(data_tensor, (0, padding), 'constant', 0)
    else:
        data_tensor_padded = data_tensor
    side_size = int(np.sqrt(desired_size))
    data_tensor_reshaped = data_tensor_padded.view(-1, 1, side_size, side_size)

    # Move the input tensor to the same device as the model
    data_tensor_reshaped = data_tensor_reshaped.to(device)

    # Debugging information
    #print(f"Model device: {next(model.parameters()).device}")
    #print(f"Data tensor device: {data_tensor_reshaped.device}")

    # Predict and calculate probabilities for the single record
    with torch.no_grad():
        outputs = model(data_tensor_reshaped)
        probabilities = F.softmax(outputs, dim=1)
        probabilities_np = probabilities.detach().cpu().numpy()
        probabilities_np_rounded = np.round(probabilities_np, decimals=3)

        _, predicted = torch.max(outputs, 1)
        predicted_np = predicted.detach().cpu().numpy()
    
    predicted_label = "BENIGN" if predicted_np[0] == 1 else "MALIGN"
    result = "WRONG"
    if (original_label.startswith("benign") and predicted_label == "BENIGN") or (not original_label.startswith("benign") and predicted_label == "MALIGN"):
        result = "OK"

    print(f"{result} | {domain_name} - {original_label} - predict: {predicted_label} | {probabilities_np_rounded}")
# Out:
# WRONG | p24.dynect.net - benign_2310:unknown - predict: MALIGN | [[0.948 0.052]]
# OK | policy.revasia.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | investvoyager.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | foxtv.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | griml.com - misp_2310:phishing - predict: BENIGN | [[0. 1.]]
# OK | epdg.epc.mnc001.mcc250.pub.3gppnetwork.org - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | www.convert-me.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | static-lax3-2.xx.fbcdn.net - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | samsung.cn - benign_2310:unknown - predict: MALIGN | [[0.999 0.001]]
# OK | pottery-barn.o3ae.net - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | velaw.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | katapult.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | sindonews.net - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | pod51249.tm-3.office.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | kmib.co.kr - benign_2310:unknown - predict: MALIGN | [[1. 0.]]
# OK | f54cbe36-23a9-4505-85fe-e251f80ec34d.organizations.api.brightspace.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | www.thediaryofarealhousewife.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | abtasty.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | www.mysuncoast.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | www.wideopencountry.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | vitalitymedical.attn.tv - benign_2310:unknown - predict: MALIGN | [[1. 0.]]
# OK | app.certainly.io - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | i2-prod.business-live.co.uk - benign_2310:unknown - predict: MALIGN | [[1. 0.]]
# OK | p23-imap.mail.me.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | pbpms.de - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | external.fhkg3-2.fna.fbcdn.net - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | store.viveport.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | mconf.douyucdn.cn - benign_2310:unknown - predict: BENIGN | [[0.261 0.739]]
# WRONG | verifica-secur.212-73-134-161.cprapid.com - phishing_since_2402:phishing - predict: BENIGN | [[0. 1.]]
# OK | sas-v3.trafficmanager.net - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | external.fsin10-1.fna.fbcdn.net - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | app.practicenumbers.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | o245736.ingest.sentry.io - benign_2310:unknown - predict: BENIGN | [[0.002 0.998]]
# WRONG | dev-lineaoccidentehn.pantheonsite.io - misp_2310:phishing - predict: BENIGN | [[0. 1.]]
# OK | cdn.apple-livephotoskit.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | img-cdn.mailsrv-e.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | s.yam.com - phishing_since_2402:phishing - predict: BENIGN | [[0.003 0.997]]
# WRONG | ezone.ulifestyle.com.hk - benign_2310:unknown - predict: MALIGN | [[1. 0.]]
# WRONG | kbs.co.kr - benign_2310:unknown - predict: MALIGN | [[1. 0.]]
# OK | external-sof1-1.xx.fbcdn.net - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | itmr.de - benign_2310:unknown - predict: BENIGN | [[0.163 0.837]]
# OK | www.smoking-meat.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | www.pocketcard.co.jp.bzdntv.top - misp_2310:phishing - predict: BENIGN | [[0. 1.]]
# WRONG | feedback.talkline.cn - benign_2310:unknown - predict: MALIGN | [[1. 0.]]
# OK | calcalist-cdnwiz.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | fqro2-1.fna.fbcdn.net - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | rr1---sn-2uuxa3vh-ngb6.googlevideo.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | creativefabrica.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | autumn-heart-fddd.uxzpxxlb.workers.dev - phishing_since_2402:phishing - predict: BENIGN | [[0. 1.]]
# OK | ntp2.your.org - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | es35.mycliplister.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | cnhionline.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | cruisecritic.d1.sc.omtrdc.net - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | gslb6.sakura.ne.jp - benign_2310:unknown - predict: MALIGN | [[0.629 0.371]]
# WRONG | settings.cashwalklabs.io - benign_2310:unknown - predict: MALIGN | [[0.99 0.01]]
# OK | moviefone.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | www.thesaurus.net - benign_2310:unknown - predict: MALIGN | [[1. 0.]]
# OK | systemstatus.sportsyou.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | locus-r.wbx2.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | media.komchadluek.net - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | montclair.edu - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | nueorv69erv.yourtrap.com - misp_2310:phishing - predict: BENIGN | [[0. 1.]]
# WRONG | chanage.agrarsemillas.com - misp_2310:phishing - predict: BENIGN | [[0. 1.]]
# WRONG | pub-f1aa859f7d8f4b3ba0d29428c524cf0a.r2.dev - phishing_since_2402:phishing - predict: BENIGN | [[0. 1.]]
# WRONG | web-hive.com - phishing_since_2402:phishing - predict: BENIGN | [[0. 1.]]
# WRONG | rebremezeret.web.app - misp_2310:phishing - predict: BENIGN | [[0. 1.]]
# WRONG | fatura-segur-forca22.blogspot.com - misp_2310:phishing - predict: BENIGN | [[0. 1.]]
# WRONG | 168528620scrtymyacn.co.vu - misp_2310:phishing - predict: BENIGN | [[0. 1.]]
# OK | citiin.tt.omtrdc.net - benign_2310:unknown - predict: BENIGN | [[0.158 0.842]]
# WRONG | sp249550.sitebeat.crazydomains.com - misp_2310:phishing - predict: BENIGN | [[0. 1.]]
# WRONG | dale.performax.cz - benign_2310:unknown - predict: MALIGN | [[1. 0.]]
# OK | avira-update.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | identity.apple.com.akadns.net - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | www.poly.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | autoremind.us - benign_2310:unknown - predict: MALIGN | [[1. 0.]]
# WRONG | eea.europa.eu - benign_2310:unknown - predict: MALIGN | [[1. 0.]]
# OK | www.coupons.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | pennfoster.edu - benign_2310:unknown - predict: MALIGN | [[1. 0.]]
# WRONG | attupdateinx.boxmode.io - misp_2310:phishing - predict: BENIGN | [[0.004 0.996]]
# OK | video.fsgn2-4.fna.fbcdn.net - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | withum.app.box.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | radaris.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | www.ipleak.net - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | prod.mbplayer.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | myapps-ecc.uhc.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | secure.nordstrom.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | advertiserreports.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | e.pic.mangatoon.mobi - benign_2310:unknown - predict: MALIGN | [[1. 0.]]
# WRONG | aol-109737.weeblysite.com - phishing_since_2402:phishing - predict: BENIGN | [[0. 1.]]
# OK | iai-shop.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | jmhwdgnrbx.photoautomat.asia - misp_2310:phishing - predict: BENIGN | [[0.004 0.996]]
# OK | alt3.gmr-smtp-in.l.google.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | webapi.narrpr.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | keyringapp.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | www.themodestman.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | ci-bfp.aws-stsd.capitalonegslbex.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# WRONG | maliyeistrgov-tr5319.com - phishing_since_2402:phishing - predict: BENIGN | [[0. 1.]]
# OK | ithinkfi.org - benign_2310:unknown - predict: BENIGN | [[0.016 0.984]]
# OK | tags.feedad.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
# OK | edge-038.ussea3.icloud-content.com - benign_2310:unknown - predict: BENIGN | [[0. 1.]]
